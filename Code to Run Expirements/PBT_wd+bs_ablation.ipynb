# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/cifar-10/cifar-10-batches-py/data_batch_1
# /kaggle/input/cifar-10/cifar-10-batches-py/data_batch_2
# /kaggle/input/cifar-10/cifar-10-batches-py/batches.meta
# /kaggle/input/cifar-10/cifar-10-batches-py/test_batch
# /kaggle/input/cifar-10/cifar-10-batches-py/data_batch_3
# /kaggle/input/cifar-10/cifar-10-batches-py/data_batch_5
# /kaggle/input/cifar-10/cifar-10-batches-py/data_batch_4
# /kaggle/input/cifar-10/cifar-10-batches-py/readme.html

# %% [markdown]
# ## This file is used to run both the BS and BS+WD ablations. Manually adjust the function calls for run_pbt_expirement_vit and then run

# %%
import copy
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as T

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)

DATA_ROOT = "/kaggle/input/cifar-10"

transform_train = T.Compose([
    T.RandomCrop(32, padding=4),
    T.RandomHorizontalFlip(),
    T.ToTensor(),
])

transform_val = T.Compose([
    T.ToTensor(),
])

train_dataset = torchvision.datasets.CIFAR10(
    root=DATA_ROOT,
    train=True,
    download=False,   # IMPORTANT: Kaggle already has the data
    transform=transform_train,
)

val_dataset = torchvision.datasets.CIFAR10(
    root=DATA_ROOT,
    train=False,
    download=False,
    transform=transform_val,
)

train_loader = DataLoader(
    train_dataset,
    batch_size=128,
    shuffle=True,
    num_workers=4,
    pin_memory=True,
)

val_loader = DataLoader(
    val_dataset,
    batch_size=256,
    shuffle=False,
    num_workers=4,
    pin_memory=True,
)
class TransformerBlock(nn.Module):
    def _init_(self, dim, num_heads, mlp_ratio=4.0, dropout=0.1):
        super()._init_()
        self.norm1 = nn.LayerNorm(dim)
        self.attn = nn.MultiheadAttention(
            embed_dim=dim,
            num_heads=num_heads,
            dropout=dropout,
            batch_first=True,
        )
        self.norm2 = nn.LayerNorm(dim)

        hidden_dim = int(dim * mlp_ratio)
        self.mlp = nn.Sequential(
            nn.Linear(dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, dim),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        attn_out, _ = self.attn(self.norm1(x), self.norm1(x), self.norm1(x), need_weights=False)
        x = x + attn_out
        x = x + self.mlp(self.norm2(x))
        return x
# Out:
# Using device: cuda

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
import numpy as np
import random
import copy
from typing import List, Dict, Any, Tuple, Optional
import matplotlib.pyplot as plt
from dataclasses import dataclass, field
import time
import math
from functools import wraps
import os
from google.colab import drive

# ---------------------------
# ViT Architecture (from grid_vit_cifar10.py)
# ---------------------------

class DropPath(nn.Module):
    def __init__(self, drop_prob: float = 0.0):
        super().__init__()
        self.drop_prob = drop_prob

    def forward(self, x):
        if self.drop_prob == 0.0 or not self.training:
            return x
        keep_prob = 1.0 - self.drop_prob
        shape = (x.shape[0],) + (1,) * (x.ndim - 1)
        random_tensor = keep_prob + torch.rand(shape, dtype=x.dtype, device=x.device)
        random_tensor.floor_()
        return x.div(keep_prob) * random_tensor

class MLP(nn.Module):
    def __init__(self, dim, mlp_ratio=4, drop=0.0):
        super().__init__()
        hidden = int(dim * mlp_ratio)
        self.fc1 = nn.Linear(dim, hidden)
        self.act = nn.GELU()
        self.fc2 = nn.Linear(hidden, dim)
        self.drop = nn.Dropout(drop)

    def forward(self, x):
        x = self.fc1(x)
        x = self.act(x)
        x = self.drop(x)
        x = self.fc2(x)
        x = self.drop(x)
        return x

class Attention(nn.Module):
    def __init__(self, dim, num_heads=6, qkv_bias=True, attn_drop=0.0, proj_drop=0.0):
        super().__init__()
        assert dim % num_heads == 0
        self.num_heads = num_heads
        self.head_dim = dim // num_heads
        self.scale = self.head_dim ** -0.5

        self.qkv = nn.Linear(dim, dim * 3, bias=qkv_bias)
        self.attn_drop = nn.Dropout(attn_drop)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(proj_drop)

    def forward(self, x):
        B, N, C = x.shape
        qkv = self.qkv(x)  # B, N, 3C
        qkv = qkv.reshape(B, N, 3, self.num_heads, self.head_dim).permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]  # each: B, heads, N, head_dim

        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        attn = self.attn_drop(attn)

        out = attn @ v  # B, heads, N, head_dim
        out = out.transpose(1, 2).reshape(B, N, C)
        out = self.proj(out)
        out = self.proj_drop(out)
        return out

class Block(nn.Module):
    def __init__(self, dim, num_heads, mlp_ratio, drop=0.0, attn_drop=0.0, drop_path=0.0):
        super().__init__()
        self.norm1 = nn.LayerNorm(dim)
        self.attn = Attention(dim, num_heads=num_heads, attn_drop=attn_drop, proj_drop=drop)
        self.drop_path = DropPath(drop_path)
        self.norm2 = nn.LayerNorm(dim)
        self.mlp = MLP(dim, mlp_ratio=mlp_ratio, drop=drop)

    def forward(self, x):
        x = x + self.drop_path(self.attn(self.norm1(x)))
        x = x + self.drop_path(self.mlp(self.norm2(x)))
        return x

class PatchEmbed(nn.Module):
    def __init__(self, img_size=32, patch_size=4, in_chans=3, embed_dim=384):
        super().__init__()
        assert img_size % patch_size == 0
        self.grid = img_size // patch_size  # 8
        self.num_patches = self.grid * self.grid  # 64
        self.proj = nn.Conv2d(in_chans, embed_dim, kernel_size=patch_size, stride=patch_size)

    def forward(self, x):
        x = self.proj(x)  # B, C, 8, 8
        x = x.flatten(2).transpose(1, 2)  # B, 64, C
        return x

class ViTSmallCIFAR(nn.Module):
    def __init__(self, num_classes=10, img_size=32, patch_size=4,
                 embed_dim=384, depth=12, num_heads=6, mlp_ratio=4.0,
                 drop_rate=0.0, attn_drop_rate=0.0, drop_path_rate=0.0,
                 cls_norm=True):
        super().__init__()
        self.patch_embed = PatchEmbed(img_size, patch_size, 3, embed_dim)
        num_patches = self.patch_embed.num_patches

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))
        self.pos_drop = nn.Dropout(p=drop_rate)

        # stochastic depth decay rule
        dpr = torch.linspace(0, drop_path_rate, steps=depth).tolist()

        self.blocks = nn.ModuleList([
            Block(embed_dim, num_heads, mlp_ratio,
                  drop=drop_rate, attn_drop=attn_drop_rate, drop_path=dpr[i])
            for i in range(depth)
        ])
        self.norm = nn.LayerNorm(embed_dim)
        self.cls_norm = cls_norm
        self.head = nn.Linear(embed_dim, num_classes)

        nn.init.trunc_normal_(self.pos_embed, std=0.02)
        nn.init.trunc_normal_(self.cls_token, std=0.02)
        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            nn.init.trunc_normal_(m.weight, std=0.02)
            if m.bias is not None:
                nn.init.zeros_(m.bias)
        elif isinstance(m, nn.LayerNorm):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)

    def forward(self, x):
        B = x.shape[0]
        x = self.patch_embed(x)  # B, 64, C
        cls = self.cls_token.expand(B, -1, -1)
        x = torch.cat([cls, x], dim=1)  # B, 65, C
        x = x + self.pos_embed
        x = self.pos_drop(x)
        for blk in self.blocks:
            x = blk(x)
        if self.cls_norm:
            x = self.norm(x)
        cls_tok = x[:, 0]
        logits = self.head(cls_tok)
        return logits

# %%
# ---------------------------
# Warmup Cosine LR Scheduler
# ---------------------------

class WarmupCosineLR(optim.lr_scheduler._LRScheduler):
    def __init__(self, optimizer, total_steps, warmup_steps=0, min_lr=1e-5, last_epoch=-1):
        self.total_steps = total_steps
        self.warmup_steps = warmup_steps
        self.min_lr = min_lr
        super().__init__(optimizer, last_epoch)

    def get_lr(self):
        step = self.last_epoch + 1
        lrs = []
        for base_lr in self.base_lrs:
            if step < self.warmup_steps:
                lr = base_lr * float(step) / float(max(1, self.warmup_steps))
            else:
                progress = (step - self.warmup_steps) / float(max(1, self.total_steps - self.warmup_steps))
                cosine = 0.5 * (1.0 + math.cos(math.pi * progress))
                lr = self.min_lr + (base_lr - self.min_lr) * cosine
            lrs.append(lr)
        return lrs

# ---------------------------
# Timer Class
# ---------------------------

class PBTTimer:
    """Timer class for tracking PBT experiment timing"""
    def __init__(self):
        self.metrics = {
            'total_start': None,
            'total_end': None,
            'epoch_times': [],
            'member_times': [],  # [epoch][member]
            'update_times': [],
            'member_details': {},  # {member_id: [times]}
            'batch_size_history': []  # [epoch][member_batch_size]
        }

    def start_total(self):
        """Start overall timer"""
        self.metrics['total_start'] = time.time()

    def end_total(self):
        """End overall timer"""
        self.metrics['total_end'] = time.time()

    def get_total_time(self):
        """Get total runtime"""
        if self.metrics['total_start'] and self.metrics['total_end']:
            return self.metrics['total_end'] - self.metrics['total_start']
        return 0

    def start_epoch(self):
        """Start timing an epoch"""
        self.current_epoch_start = time.time()
        self.current_member_times = []
        self.current_batch_sizes = []

    def end_epoch(self):
        """End timing an epoch"""
        if hasattr(self, 'current_epoch_start'):
            epoch_time = time.time() - self.current_epoch_start
            self.metrics['epoch_times'].append(epoch_time)
            self.metrics['member_times'].append(self.current_member_times)
            self.metrics['batch_size_history'].append(self.current_batch_sizes)

    def time_member(self, member_id: int, batch_size: int = None):
        """Context manager for timing member training"""
        class MemberTimer:
            def __init__(self, timer, member_id, batch_size):
                self.timer = timer
                self.member_id = member_id
                self.batch_size = batch_size

            def __enter__(self):
                self.start = time.time()
                return self

            def __exit__(self, *args):
                elapsed = time.time() - self.start
                self.timer.current_member_times.append(elapsed)
                self.timer.current_batch_sizes.append(self.batch_size)

                # Track detailed member times
                if self.member_id not in self.timer.metrics['member_details']:
                    self.timer.metrics['member_details'][self.member_id] = []
                self.timer.metrics['member_details'][self.member_id].append(elapsed)

        return MemberTimer(self, member_id, batch_size)

    def time_update(self):
        """Context manager for timing population updates"""
        class UpdateTimer:
            def __init__(self, timer):
                self.timer = timer

            def __enter__(self):
                self.start = time.time()
                return self

            def __exit__(self, *args):
                elapsed = time.time() - self.start
                self.timer.metrics['update_times'].append(elapsed)

        return UpdateTimer(self)

    def print_report(self):
        """Print detailed timing report"""
        total = self.get_total_time()
        epoch_times = self.metrics['epoch_times']
        member_times = self.metrics['member_times']
        update_times = self.metrics['update_times']
        batch_history = self.metrics['batch_size_history']

        print(f"\n{'='*70}")
        print(f"{'PBT TIMING REPORT':^70}")
        print(f"{'='*70}")

        # Overall statistics
        print(f"\n{'Overall Statistics':<40} {'Value':<30}")
        print(f"{'-'*70}")
        print(f"{'Total runtime':<40} {total:.2f}s ({total/60:.2f} min)")
        print(f"{'Number of epochs':<40} {len(epoch_times)}")
        print(f"{'Number of population updates':<40} {len([t for t in update_times if t > 0])}")

        # Epoch timing
        avg_epoch = np.mean(epoch_times)
        std_epoch = np.std(epoch_times)
        print(f"\n{'Epoch Timing':<40} {'Value':<30}")
        print(f"{'-'*70}")
        print(f"{'Average epoch time':<40} {avg_epoch:.2f}s")
        print(f"{'Std epoch time':<40} {std_epoch:.2f}s")
        print(f"{'Min epoch time':<40} {min(epoch_times):.2f}s (epoch {np.argmin(epoch_times)+1})")
        print(f"{'Max epoch time':<40} {max(epoch_times):.2f}s (epoch {np.argmax(epoch_times)+1})")

        # Member training timing
        all_member_times = [t for epoch_times in member_times for t in epoch_times]
        avg_member_time = np.mean(all_member_times)
        total_training_time = sum(all_member_times)

        print(f"\n{'Member Training Timing':<40} {'Value':<30}")
        print(f"{'-'*70}")
        print(f"{'Average member time per epoch':<40} {avg_member_time:.2f}s")
        print(f"{'Total training time':<40} {total_training_time:.2f}s")
        print(f"{'Training efficiency':<40} {(total_training_time/total*100):.1f}%")

        # Population update timing
        non_zero_updates = [t for t in update_times if t > 0]
        if non_zero_updates:
            avg_update = np.mean(non_zero_updates)
            total_update = sum(update_times)

            print(f"\n{'Population Update Timing':<40} {'Value':<30}")
            print(f"{'-'*70}")
            print(f"{'Average update time':<40} {avg_update:.2f}s")
            print(f"{'Total update time':<40} {total_update:.2f}s")
            print(f"{'Update efficiency':<40} {(total_update/total*100):.1f}%")

        # Batch size correlation
        if batch_history and len(batch_history[0]) > 0:
            batch_times = []
            for epoch_idx, batch_sizes in enumerate(batch_history):
                for member_idx, bs in enumerate(batch_sizes):
                    batch_times.append((bs, member_times[epoch_idx][member_idx]))

            # Group by batch size
            batch_stats = {}
            for bs, t in batch_times:
                if bs not in batch_stats:
                    batch_stats[bs] = []
                batch_stats[bs].append(t)

            print(f"\n{'Batch Size Analysis':<40} {'Avg Time':<15} {'Samples':<15}")
            print(f"{'-'*70}")
            for bs in sorted(batch_stats.keys()):
                avg_time = np.mean(batch_stats[bs])
                samples = len(batch_stats[bs])
                print(f"{f'Batch size {bs}':<40} {avg_time:.2f}s{'':<5} {samples:<15}")

        # Per-member statistics
        print(f"\n{'Per-Member Statistics':<40} {'Avg Time':<15} {'Total Time':<15}")
        print(f"{'-'*70}")
        for member_id in sorted(self.metrics['member_details'].keys()):
            times = self.metrics['member_details'][member_id]
            avg_time = np.mean(times)
            total_time = sum(times)
            print(f"{f'Member {member_id}':<40} {avg_time:.2f}s{'':<5} {total_time:.2f}s")

        print(f"\n{'='*70}")

# ---------------------------
# PBT Configuration
# ---------------------------

@dataclass
class PBTConfig:
    # Population settings
    population_size: int = 4  # Smaller for memory constraints
    exploit_interval: int = 5  # Exploit every 5 epochs
    truncation_factor: float = 0.25  # top 25% replace bottom 25%

    # ViT-specific hyperparameter search spaces
    lr_bounds: Tuple[float, float] = (1e-4, 1e-3)
    weight_decay_bounds: Tuple[float, float] = (0.05, 0.30)   
    drop_path_bounds: Tuple[float, float] = (0.0, 0.2)      
    warmup_epochs_bounds: Tuple[int, int] = (5, 5)
    batch_size_bounds: Tuple[int, int] = (256, 256)  # Batch size search space

    # Training settings
    epochs: int = 70  # Shorter run for demonstration
    min_lr: float = 1e-6

    # Model architecture (fixed for ViT-Small)
    embed_dim: int = 192
    depth: int = 12
    num_heads: int = 3
    mlp_ratio: float = 4.0
    patch_size: int = 8
    img_size: int = 32
    drive_base_path: str = '/content/drive/MyDrive/Colab_Checkpoints'
    seed: int = None

# %%
# ---------------------------
# PBT Member
# ---------------------------

class PBTMember:
    def __init__(self, model_class, model_args, hyperparams: Dict[str, float], member_id: int,
                 total_epochs: int, min_lr: float = 1e-6):
        self.member_id = member_id
        self.hyperparams = hyperparams
        self.total_epochs = total_epochs
        self.batch_size = hyperparams['batch_size']  # Get batch size from hyperparams
        self.min_lr = min_lr

        # NEW: Track LR history
        self.lr_history = []  # Store LR at each epoch
        self.current_lr = hyperparams['lr']  # Track current LR

        # Create ViT model with specific hyperparameters
        model_args['drop_path_rate'] = hyperparams['drop_path']
        self.model = model_class(**model_args)

        # AdamW optimizer for ViT
        self.optimizer = optim.AdamW(
            self.model.parameters(),
            lr=hyperparams['lr'],
            weight_decay=hyperparams['weight_decay'],
            betas=(0.9, 0.999),
            eps=1e-8
        )

        # Scheduler will be setup when dataloader is available
        self.scheduler = None

        # Tracking
        self.performance_history = []
        self.current_performance = 0.0
        self.steps = 0
        self.epoch = 0



    def setup_scheduler(self, train_loader_length: int, warmup_epochs: int):
        """Setup scheduler with correct total steps based on batch size"""
        total_steps = self.total_epochs * train_loader_length
        warmup_steps = warmup_epochs * train_loader_length
        self.scheduler = WarmupCosineLR(
            self.optimizer,
            total_steps=total_steps,
            warmup_steps=warmup_steps,
            min_lr=self.min_lr
        )

    def update_hyperparams(self, new_hyperparams: Dict[str, float]):
        """Update hyperparameters"""
        old_hyperparams = copy.deepcopy(self.hyperparams)
        self.hyperparams = new_hyperparams
        self.batch_size = new_hyperparams['batch_size']  # Update batch size
        self.current_lr = new_hyperparams['lr'] # Update current LR

        # Log LR change
        for key, val in old_hyperparams.items():
          if old_hyperparams[key] != new_hyperparams[key]:
            print(f"Member {self.member_id}: {key} changed from {val} to {new_hyperparams[key]}")


        # Update optimizer
        self.optimizer = optim.AdamW(
            self.model.parameters(),
            lr=new_hyperparams['lr'],
            weight_decay=new_hyperparams['weight_decay'],
            betas=(0.9, 0.999),
            eps=1e-8
        )

        # Reset scheduler (will be setup with new dataloader)
        self.scheduler = None


    def record_lr(self, epoch_lr: float = None):
      if epoch_lr is not None:
          self.lr_history.append(epoch_lr)
      else:
          # Get current LR from optimizer
          current_lr = self.optimizer.param_groups[0]['lr']
          self.lr_history.append(current_lr)
          self.current_lr = current_lr

    def update_weights(self, new_weights):
        self.model.load_state_dict(new_weights)

    def save_checkpoint(self):
        """Save model and optimizer state"""
        return {
            'model_state': copy.deepcopy(self.model.state_dict()),
            'optimizer_state': copy.deepcopy(self.optimizer.state_dict()),
            'scheduler_state': copy.deepcopy(self.scheduler.state_dict()) if self.scheduler else None,
            'hyperparams': copy.deepcopy(self.hyperparams),
            'performance': self.current_performance,
            'steps': self.steps,
            'epoch': self.epoch
        }

    def load_checkpoint(self, checkpoint):
        """Load model, optimizer, and scheduler state"""
        self.model.load_state_dict(checkpoint['model_state'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state'])
        if checkpoint['scheduler_state']:
            # Need to initialize scheduler before loading state_dict if it's not None
            # This assumes `setup_scheduler` would have been called before loading if it's not the first epoch
            if self.scheduler is None: # Placeholder if scheduler wasn't setup yet (e.g., loading into a fresh member obj)
                # This case is tricky, requires knowing train_loader_length etc.
                # For PBT, usually scheduler is reset/re-setup after hyperparam changes or init
                # For now, rely on `setup_scheduler` being called after `load_checkpoint` if needed.
                pass # Or raise an error/warning
            else:
                self.scheduler.load_state_dict(checkpoint['scheduler_state'])

        self.hyperparams = checkpoint['hyperparams']
        self.batch_size = checkpoint['hyperparams']['batch_size']
        self.current_performance = checkpoint['performance']
        self.steps = checkpoint['steps']
        self.epoch = checkpoint['epoch']

# ---------------------------
# Google Drive Checkpointing Helpers
# ---------------------------

# def mount_drive_if_not_mounted():
#     """Mounts Google Drive if it's not already mounted."""
#     if not os.path.exists('/content/drive'):
#         print("Google Drive not mounted. Mounting now...")
#         drive.mount('/content/drive')
#     else:
#         print("Google Drive already mounted.")

# def save_member_checkpoint_to_drive(member: PBTMember, drive_base_path: str, seed):
#     """
#     Saves a member's checkpoint to Google Drive with specified filename format, overwriting if exists.

#     Args:
#         member (PBTMember): The PBT member object.
#         drive_base_path (str): The base path in Google Drive (e.g., '/content/drive/MyDrive/Colab_Checkpoints').
#     """
#     # Ensure Drive is mounted
#     mount_drive_if_not_mounted()

#     # Construct the target directory and ensure it exists
#     # Filename format: model_{member_id}_seed_{member_id}.pt (member_id serves as 'seed' here)
#     checkpoint_dir = os.path.join(drive_base_path, "pbt_checkpoints")
#     os.makedirs(checkpoint_dir, exist_ok=True)

#     checkpoint_filename = os.path.join(checkpoint_dir, f"model_{member.member_id}_seed_{seed}.pt")

#     checkpoint_data = {
#         'model_state': member.model.state_dict(),
#         'optimizer_state': member.optimizer.state_dict(),
#         'scheduler_state': member.scheduler.state_dict() if member.scheduler else None,
#         'hyperparams': member.hyperparams,
#         'performance': member.current_performance,
#         'steps': member.steps,
#         'epoch': member.epoch
#     }

#     torch.save(checkpoint_data, checkpoint_filename)
#     print(f"Member {member.member_id}: Checkpoint saved to {checkpoint_filename}")


# ---------------------------
# Population Based Training
# ---------------------------

class PopulationBasedTraining:
    def __init__(self, config: PBTConfig, model_class, model_args):
        self.config = config
        self.model_class = model_class
        self.model_args = model_args
        self.population: List[PBTMember] = []
        self.best_performance = 0.0
        self.best_member = None

    def initialize_population(self):
        """Initialize population with random hyperparameters including batch size"""
        for i in range(self.config.population_size):
            hyperparams = {
                'lr': self._sample_log_uniform(*self.config.lr_bounds),
                'weight_decay': random.uniform(*self.config.weight_decay_bounds),
                'drop_path': random.uniform(*self.config.drop_path_bounds),
                'warmup_epochs': random.randint(*self.config.warmup_epochs_bounds),
                'batch_size': self._sample_batch_size()
            }

            member = PBTMember(
                model_class=self.model_class,
                model_args=self.model_args,
                hyperparams=hyperparams,
                member_id=i,
                total_epochs=self.config.epochs,
                min_lr=self.config.min_lr
            )
            self.population.append(member)

    def _sample_log_uniform(self, low, high):
        """Sample from log-uniform distribution"""
        return np.exp(random.uniform(np.log(low), np.log(high)))

    def _sample_batch_size(self):
        """Sample batch size from discrete options within bounds"""
        batch_options = [64, 128, 256, 512]
        valid_options = [bs for bs in batch_options
                        if self.config.batch_size_bounds[0] <= bs <= self.config.batch_size_bounds[1]]
        return random.choice(valid_options)

    def _perturb_hyperparam(self, value, bounds, is_log=True):
        """Perturb hyperparameter with random noise"""
        if is_log:
            low, high = np.log(bounds[0]), np.log(bounds[1])
            current = np.log(value)
        else:
            low, high = bounds
            current = value

        # Random walk with reflection at boundaries
        perturbed = current + random.uniform(-0.2, 0.2) * (high - low)
        perturbed = max(min(perturbed, high), low)  # Clip to bounds

        return np.exp(perturbed) if is_log else perturbed

    def _perturb_batch_size(self, current_batch_size):
        """Perturb batch size within discrete options"""
        batch_options = [64, 128, 256, 512]
        # Filter options within bounds
        valid_options = [bs for bs in batch_options
                        if self.config.batch_size_bounds[0] <= bs <= self.config.batch_size_bounds[1]]

        if current_batch_size not in valid_options:
            return random.choice(valid_options)

        current_idx = valid_options.index(current_batch_size)
        # Move up or down by 1 step (or stay same)
        new_idx = current_idx + random.choice([-1, 0, 1])
        new_idx = max(0, min(new_idx, len(valid_options) - 1))

        return valid_options[new_idx]

    def exploit_and_explore(self):
        """PBT core algorithm for ViT - FIXED VERSION"""
        # Rank population by performance
        ranked_members = sorted(self.population,
                              key=lambda x: x.current_performance,
                              reverse=True)
    
        # FIX: Ensure at least 1 member is selected for truncation
        num_truncate = max(1, int(self.config.truncation_factor * self.config.population_size))
        
        # Additional safety check: don't truncate more than half the population
        num_truncate = min(num_truncate, self.config.population_size // 2)
        
        # If population is too small for meaningful truncation, skip
        if num_truncate == 0 or len(ranked_members) < 2:
            print(f"Population too small (size={len(ranked_members)}) for truncation. Skipping exploit/explore.")
            return
    
        top_members = ranked_members[:num_truncate]
        bottom_members = ranked_members[-num_truncate:]
    
        print(f"\n=== PBT Exploit & Explore ===")
        print(f"Truncating {num_truncate} members")
        print(f"Top performers: {[f'{m.current_performance:.2f}%' for m in top_members]}")
        print(f"Bottom performers: {[f'{m.current_performance:.2f}%' for m in bottom_members]}")
    
        # Exploit: Copy from top to bottom
        for bottom_member in bottom_members:
            # Randomly select a top member to copy from
            donor = random.choice(top_members)
            better_weights = donor.model.state_dict()
            bottom_member.update_weights(better_weights)

            # Explore: Perturb hyperparameters
            new_hyperparams = {
                'lr': self._perturb_hyperparam(
                    bottom_member.hyperparams['lr'],
                    self.config.lr_bounds,
                    is_log=True
                ),
                'weight_decay': self._perturb_hyperparam(
                    bottom_member.hyperparams['weight_decay'],
                    self.config.weight_decay_bounds,
                    is_log=False
                ),
                'drop_path': self._perturb_hyperparam(
                    bottom_member.hyperparams['drop_path'],
                    self.config.drop_path_bounds,
                    is_log=False
                ),
                'warmup_epochs': int(np.clip(
                    bottom_member.hyperparams['warmup_epochs'] + random.randint(-2, 2),
                    self.config.warmup_epochs_bounds[0],
                    self.config.warmup_epochs_bounds[1]
                )),
                'batch_size': self._perturb_batch_size(bottom_member.hyperparams['batch_size'])
            }
    
            bottom_member.update_hyperparams(new_hyperparams)
    
            print(f"Member {bottom_member.member_id} copied from {donor.member_id}")
            print(f"  LR={new_hyperparams['lr']:.2e}, WD={new_hyperparams['weight_decay']:.3f}, "
                  f"DropPath={new_hyperparams['drop_path']:.3f}, "
                  f"Warmup={new_hyperparams['warmup_epochs']} epochs, "
                  f"Batch={new_hyperparams['batch_size']}")
                

    def train_member_one_epoch(self, member: PBTMember, train_loader, device, scaler):
        """Train one ViT member for one epoch with mixed precision"""
        start = time.time()
        member.model.train()
        member.model.to(device)

        criterion = nn.CrossEntropyLoss()
        total_loss = 0.0
        correct = 0
        total = 0

        # Store LR at the start of epoch
        start_lr = member.optimizer.param_groups[0]['lr']



        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)

            member.optimizer.zero_grad(set_to_none=True)

            # Mixed precision training
            with torch.amp.autocast('cuda', enabled=torch.cuda.is_available()):
                output = member.model(data)
                loss = criterion(output, target)

            scaler.scale(loss).backward()
            scaler.step(member.optimizer)
            scaler.update()

            # Update scheduler if available (changes LR!)
            if member.scheduler:
                member.scheduler.step()

            total_loss += loss.item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
            total += target.size(0)
            member.steps += 1

        accuracy = 100. * correct / total
        avg_loss = total_loss / len(train_loader)

        # Record LR at the end of epoch
        end_lr = member.optimizer.param_groups[0]['lr']
        member.lr_history.append(end_lr) # Store in history
        member.current_lr = end_lr # Update current LR

        # Track performance
        member.current_performance = accuracy
        member.performance_history.append(accuracy)
        member.epoch += 1

        # Print LR change if it occurred
        if abs(start_lr - end_lr) > 1e-10: # If LR changed during epoch
          print(f" LR changed during epoch: {start_lr:.2e} -> {end_lr:.2e}")
        print(f'total runtime to train this model was {time.time() - start} seconds')
        return avg_loss, accuracy

    def evaluate_member(self, member: PBTMember, test_loader, device):
        """Evaluate ViT member on test set"""
        member.model.eval()
        member.model.to(device)

        correct = 0
        total = 0

        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = member.model(data)
                pred = output.argmax(dim=1, keepdim=True)
                correct += pred.eq(target.view_as(pred)).sum().item()
                total += target.size(0)

        accuracy = 100. * correct / total
        member.current_performance = accuracy
        return accuracy

    def get_population_stats(self):
        """Get statistics about current population"""
        performances = [m.current_performance for m in self.population]
        lrs = [m.hyperparams['lr'] for m in self.population]
        wds = [m.hyperparams['weight_decay'] for m in self.population]
        drop_paths = [m.hyperparams['drop_path'] for m in self.population]
        warmups = [m.hyperparams['warmup_epochs'] for m in self.population]
        batch_sizes = [m.hyperparams['batch_size'] for m in self.population]

        return {
            'mean_performance': np.mean(performances),
            'std_performance': np.std(performances),
            'best_performance': np.max(performances),
            'mean_lr': np.mean(lrs),
            'mean_weight_decay': np.mean(wds),
            'mean_drop_path': np.mean(drop_paths),
            'mean_warmup': np.mean(warmups),
            'mean_batch_size': np.mean(batch_sizes),
            'batch_sizes': batch_sizes
        }

# %%
# ---------------------------
# Data Loading
# ---------------------------

def build_dataloaders(batch_size: int, num_workers: int = 4):
    """Build CIFAR-10 dataloaders"""
    train_tf = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=(0.4914, 0.4822, 0.4465),
                           std=(0.2470, 0.2435, 0.2616)),
    ])
    test_tf = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean=(0.4914, 0.4822, 0.4465),
                           std=(0.2470, 0.2435, 0.2616)),
    ])

    train_ds = torchvision.datasets.CIFAR10(root="./data", train=True, transform=train_tf, download=True)
    test_ds = torchvision.datasets.CIFAR10(root="./data", train=False, transform=test_tf, download=True)

    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True,
                            num_workers=num_workers, pin_memory=True)
    test_loader = DataLoader(test_ds, batch_size=512, shuffle=False,
                           num_workers=num_workers, pin_memory=True)
    return train_loader, test_loader

# ---------------------------
# Main Experiment
# ---------------------------

def run_pbt_vit_experiment():
    """Run PBT for ViT-Small on CIFAR-10 with comprehensive timing"""
    # Configuration
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    # Initialize timer
    timer = PBTTimer()
    timer.start_total()

    # PBT Configuration for ViT
    pbt_config = PBTConfig(
        population_size=2,
        exploit_interval=5,
        truncation_factor=0.25,
        epochs=60,  # Even shorter for quick testing        REDUCED THE EPOCHS TO 2 FROM ORIGINAL
        batch_size_bounds=(64, 256),
        # seed = 38042    # 38042, 217401          RERUN ON THOSE 2 SEED NUMBERS!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        seed = 217401
        )

    random.seed(pbt_config.seed)

    # Mount Google Drive once at the beginning of the experiment
    # mount_drive_if_not_mounted()

    # Initialize PBT for ViT
    pbt = PopulationBasedTraining(
        config=pbt_config,
        model_class=ViTSmallCIFAR,
        model_args={
            'num_classes': 10,            # CHANGED THIS FROM 5 TO 10 TO MATCH CIFAR-10
            'img_size': pbt_config.img_size,
            'patch_size': pbt_config.patch_size,
            'embed_dim': pbt_config.embed_dim,
            'depth': pbt_config.depth,
            'num_heads': pbt_config.num_heads,
            'mlp_ratio': pbt_config.mlp_ratio,
            'drop_rate': 0.0,
            'attn_drop_rate': 0.0,
            'cls_norm': True
        }
    )
    pbt.initialize_population()

    # Create gradient scaler for mixed precision
    # scaler = torch.cuda.amp.GradScaler(enabled=torch.cuda.is_available())
    scaler = torch.amp.GradScaler('cuda')

    # Training loop
    history = []
    print("Starting PBT Training for ViT-Small...")
    print(f"Population size: {pbt_config.population_size}")
    print(f"Total epochs: {pbt_config.epochs}")
    print(f"Exploit interval: {pbt_config.exploit_interval} epochs")
    # print(f"Checkpoints will be saved to: {pbt_config.drive_base_path}")

    for epoch in range(pbt_config.epochs):
        print(f"\n{'='*60}")
        print(f"Epoch {epoch + 1}/{pbt_config.epochs}")
        print(f"{('='*60)}")

        # Start timing this epoch
        timer.start_epoch()

        # Train all members
        for i, member in enumerate(pbt.population):
            print(f"\n--- Training Member {i} (Batch size: {member.batch_size}) ---")

            # Time member training
            with timer.time_member(member.member_id, member.batch_size):
                start_t = time.time()
                # Create dataloader for this member's batch size
                train_loader, test_loader = build_dataloaders(
                    batch_size=member.batch_size,
                    num_workers=2
                )

                # Setup scheduler if needed
                if member.scheduler is None:
                    member.setup_scheduler(
                        train_loader_length=len(train_loader),
                        warmup_epochs=member.hyperparams['warmup_epochs']
                    )
                print(f'built data in {time.time() - start_t} seconds')

                # Train member
                loss, train_acc = pbt.train_member_one_epoch(member, train_loader, device, scaler)

                # Evaluate this member
                start_t = time.time()
                test_acc = pbt.evaluate_member(member, test_loader, device)
                print(f'evaluation in {time.time() - start_t} seconds')

                print(f"  Loss: {loss:.4f}")
                print(f"  Train Accuracy: {train_acc:.2f}%")
                print(f"  Test Accuracy: {test_acc:.2f}%")

                # Save checkpoint to Google Drive after each epoch for each member
                # save_member_checkpoint_to_drive(member, pbt_config.drive_base_path, pbt_config.seed)

        # PBT step: exploit and explore
        should_update = (epoch + 1) % pbt_config.exploit_interval == 0
        if should_update:
            print(f"\n--- Population Update (Epoch {epoch + 1}) ---")
            with timer.time_update():
                pbt.exploit_and_explore()
        else:
            # Record 0 update time for non-update epochs
            timer.metrics['update_times'].append(0.0)

        # End timing this epoch
        timer.end_epoch()

        # Record statistics
        stats = pbt.get_population_stats()
        history.append(stats)

        # Print epoch summary
        epoch_time = timer.metrics['epoch_times'][-1]
        avg_member_time = np.mean(timer.metrics['member_times'][-1])

        print(f"\n{'='*60}")
        print(f"Epoch {epoch + 1} Summary:")
        print(f"{('='*60)}")
        print(f"Time: {epoch_time:.2f}s (Avg member: {avg_member_time:.2f}s)")
        print(f"Population Mean Accuracy: {stats['mean_performance']:.2f}%")
        print(f"Best Member Accuracy: {stats['best_performance']:.2f}%")
        print(f"Mean Batch Size: {stats['mean_batch_size']:.0f}")
        print(f"Mean Learning Rate: {stats['mean_lr']:.2e}")
        print(f"Mean Weight Decay: {stats['mean_weight_decay']:.3f}")

    # End overall timer
    timer.end_total()

    # Final results
    best_member = max(pbt.population, key=lambda x: x.current_performance)
    print(f"\n{'='*70}")
    print(f"{'PBT TRAINING COMPLETE':^70}")
    print(f"{'='*70}")
    print(f"Best member: {best_member.member_id}")
    print(f"Best accuracy: {best_member.current_performance:.2f}%")
    print(f"\nBest hyperparameters:")
    print(f"  Learning Rate: {best_member.hyperparams['lr']:.2e}")
    print(f"  Weight Decay: {best_member.hyperparams['weight_decay']:.3f}")
    print(f"  Drop Path Rate: {best_member.hyperparams['drop_path']:.3f}")
    print(f"  Warmup Epochs: {best_member.hyperparams['warmup_epochs']}")
    print(f"  Batch Size: {best_member.hyperparams['batch_size']}")

    # Print timing report
    timer.print_report()

    # Plot results
    plot_pbt_results_vit(history, pbt.population, timer)

    return pbt, history, timer

# ---------------------------
# Visualization
# ---------------------------

def plot_pbt_results_vit(history, population, timer):
    """Plot PBT training results with timing"""
    fig, axes = plt.subplots(3, 3, figsize=(18, 15))

    # Flatten axes for easier indexing
    axes = axes.flatten()

    # Plot 1: Population performance
    epochs = range(1, len(history) + 1)
    mean_perf = [h['mean_performance'] for h in history]
    best_perf = [h['best_performance'] for h in history]

    axes[0].plot(epochs, mean_perf, 'b-', label='Mean Population', linewidth=2)
    axes[0].plot(epochs, best_perf, 'r-', label='Best Population', linewidth=2)
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Accuracy (%)', fontsize=12)
    axes[0].set_title('ViT Population Performance', fontsize=14, fontweight='bold')
    axes[0].legend(fontsize=11)
    axes[0].grid(True, alpha=0.3)

    # Plot 2: Individual member performance
    for member in population:
        axes[1].plot(range(1, len(member.performance_history) + 1),
                    member.performance_history,
                    linewidth=1.5,
                    alpha=0.7,
                    label=f'M{member.member_id} (BS={member.batch_size})')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy (%)', fontsize=12)
    axes[1].set_title('Individual ViT Member Performance', fontsize=14, fontweight='bold')
    axes[1].legend(fontsize=10, ncol=2)
    axes[1].grid(True, alpha=0.3)

    # Plot 3: Learning rate evolution
    axes[2].clear()

    for i, member in enumerate(population):
        if len(member.lr_history) > 0:
          # Plot actual recorded LR history
          epochs_to_plot = range(1, len(member.lr_history) + 1)
          axes[2].semilogy(epochs_to_plot, member.lr_history,
                           linewidth=1.5, alpha=0.7,
                           label=f'Member {i} (BS={member.batch_size})',
                           marker='o', markersize=3)
        else:
          # Fallback: plot constant LR (shouldn't happen with tracking) THIS IS IN CASE THIS TRACKING FAILS
          epochs = range(1, len(member.performance_history) + 1)
          lrs = [member.hyperparams['lr']] * len(epochs)  # Simplified - LR changes per epoch
          axes[2].semilogy(epochs, lrs, linewidth=1.5, alpha=0.7, label=f'Member {i} (no history)')
    axes[2].set_xlabel('Epoch', fontsize=12)
    axes[2].set_ylabel('Learning Rate', fontsize=12)
    axes[2].set_title('Actual Learning Rate Evolution', fontsize=14, fontweight='bold')
    axes[2].legend(fontsize=10, ncol=2)
    axes[2].grid(True, alpha=0.3)



    # Add annotation for LR changes due to PBT
    pbt_update_epochs = []
    for epoch_idx, update_time in enumerate(timer.metrics['update_times']):
        if update_time > 0:  # PBT update occurred
            pbt_update_epochs.append(epoch_idx + 1)

    for update_epoch in pbt_update_epochs:
        axes[2].axvline(x=update_epoch, color='red', alpha=0.3, linestyle='--', linewidth=1)

    if pbt_update_epochs:
        axes[2].text(0.02, 0.98, 'Red dashes: PBT updates',
                    transform=axes[2].transAxes, fontsize=9,
                    verticalalignment='top',
                    bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))







    # Plot 4: Batch size evolution
    batch_history = timer.metrics['batch_size_history']
    for i in range(len(population)):
        batches = [epoch_batches[i] for epoch_batches in batch_history]
        axes[3].plot(epochs, batches, linewidth=2, marker='o', markersize=4, label=f'Member {i}')
    axes[3].set_xlabel('Epoch', fontsize=12)
    axes[3].set_ylabel('Batch Size', fontsize=12)
    axes[3].set_title('Batch Size Evolution', fontsize=14, fontweight='bold')
    axes[3].set_yticks([64, 128, 256])
    axes[3].legend(fontsize=10, ncol=2)
    axes[3].grid(True, alpha=0.3)

    # Plot 5: Epoch timing
    epoch_times = timer.metrics['epoch_times']
    axes[4].plot(epochs, epoch_times, 'g-', linewidth=2, marker='s', markersize=5)
    axes[4].set_xlabel('Epoch', fontsize=12)
    axes[4].set_ylabel('Time (seconds)', fontsize=12)
    axes[4].set_title('Epoch Duration', fontsize=14, fontweight='bold')
    axes[4].grid(True, alpha=0.3)
    axes[4].fill_between(epochs, 0, epoch_times, alpha=0.3, color='green')

    # Plot 6: Member training time distribution
    member_avg_times = []
    for member_id in sorted(timer.metrics['member_details'].keys()):
        avg_time = np.mean(timer.metrics['member_details'][member_id])
        member_avg_times.append(avg_time)

    bars = axes[5].bar(range(len(member_avg_times)), member_avg_times, color='skyblue')
    axes[5].set_xlabel('Member ID', fontsize=12)
    axes[5].set_ylabel('Average Training Time (seconds)', fontsize=12)
    axes[5].set_title('Average Training Time per Member', fontsize=14, fontweight='bold')
    axes[5].set_xticks(range(len(member_avg_times)))
    axes[5].grid(True, alpha=0.3, axis='y')

    # Add value labels on bars
    for bar in bars:
        height = bar.get_height()
        axes[5].text(bar.get_x() + bar.get_width()/2., height,
                    f'{height:.1f}s', ha='center', va='bottom', fontsize=9)

    # Plot 7: Batch size vs Training time
    batch_times = []
    for epoch_idx, batch_sizes in enumerate(timer.metrics['batch_size_history']):
        for member_idx, bs in enumerate(batch_sizes):
            batch_times.append((bs, timer.metrics['member_times'][epoch_idx][member_idx]))

    # Group by batch size
    batch_stats = {}
    for bs, t in batch_times:
        if bs not in batch_stats:
            batch_stats[bs] = []
        batch_stats[bs].append(t)

    batch_sizes_list = sorted(batch_stats.keys())
    avg_times = [np.mean(batch_stats[bs]) for bs in batch_sizes_list]

    bars2 = axes[6].bar(range(len(batch_sizes_list)), avg_times, color='lightcoral')
    axes[6].set_xlabel('Batch Size', fontsize=12)
    axes[6].set_ylabel('Average Training Time (seconds)', fontsize=12)
    axes[6].set_title('Batch Size vs Training Time', fontsize=14, fontweight='bold')
    axes[6].set_xticks(range(len(batch_sizes_list)))
    axes[6].set_xticklabels([str(bs) for bs in batch_sizes_list])
    axes[6].grid(True, alpha=0.3, axis='y')

    # Add value labels on bars
    for bar in bars2:
        height = bar.get_height()
        axes[6].text(bar.get_x() + bar.get_width()/2., height,
                    f'{height:.1f}s', ha='center', va='bottom', fontsize=9)

    # Plot 8: Runtime breakdown
    labels = ['Member Training', 'Population Updates', 'Other']
    training_total = sum([sum(t) for t in timer.metrics['member_times']])
    update_total = sum(timer.metrics['update_times'])
    other_total = timer.get_total_time() - training_total - update_total

    sizes = [training_total, update_total, other_total]
    colors = ['#ff9999', '#66b3ff', '#99ff99']

    axes[7].pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%',
                startangle=90, textprops={'fontsize': 10})
    axes[7].set_title('Runtime Breakdown', fontsize=14, fontweight='bold')

    # Plot 9: Final hyperparameter distribution
    final_lrs = [m.hyperparams['lr'] for m in population]
    final_batches = [m.hyperparams['batch_size'] for m in population]
    final_perf = [m.current_performance for m in population]

    scatter = axes[8].scatter(final_lrs, final_batches,
                             c=final_perf, cmap='viridis', s=200, alpha=0.8, edgecolors='k')
    axes[8].set_xscale('log')
    axes[8].set_xlabel('Learning Rate', fontsize=12)
    axes[8].set_ylabel('Batch Size', fontsize=12)
    axes[8].set_title('Final Hyperparameters vs Performance', fontsize=14, fontweight='bold')
    axes[8].set_yticks([64, 128, 256])
    plt.colorbar(scatter, ax=axes[8], label='Accuracy (%)')
    axes[8].grid(True, alpha=0.3)

    plt.suptitle('PBT for ViT-Small on CIFAR-10 with Timing Analysis',
                fontsize=16, fontweight='bold', y=1.02)
    plt.tight_layout()
    plt.savefig('pbt_vit_timing_results.png', dpi=300, bbox_inches='tight')
    plt.show()

    # Also create a separate timing visualization
    plot_timing_details(timer)

def plot_timing_details(timer):
    """Create detailed timing visualization"""
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))

    # Plot 1: Cumulative time over epochs
    cumulative_time = np.cumsum(timer.metrics['epoch_times'])
    epochs = range(1, len(cumulative_time) + 1)

    axes[0, 0].plot(epochs, cumulative_time, 'b-', linewidth=2)
    axes[0, 0].fill_between(epochs, 0, cumulative_time, alpha=0.3)
    axes[0, 0].set_xlabel('Epoch', fontsize=12)
    axes[0, 0].set_ylabel('Cumulative Time (seconds)', fontsize=12)
    axes[0, 0].set_title('Cumulative Runtime', fontsize=14, fontweight='bold')
    axes[0, 0].grid(True, alpha=0.3)

    # Plot 2: Member time progression
    for member_id in sorted(timer.metrics['member_details'].keys()):
        times = timer.metrics['member_details'][member_id]
        axes[0, 1].plot(range(1, len(times) + 1), times, linewidth=1.5,
                       label=f'Member {member_id}')
    axes[0, 1].set_xlabel('Epoch', fontsize=12)
    axes[0, 1].set_ylabel('Training Time (seconds)', fontsize=12)
    axes[0, 1].set_title('Member Training Time Progression', fontsize=14, fontweight='bold')
    axes[0, 1].legend(fontsize=10, ncol=2)
    axes[0, 1].grid(True, alpha=0.3)

    # Plot 3: Batch size vs time scatter
    all_batch_times = []
    for epoch_idx, batch_sizes in enumerate(timer.metrics['batch_size_history']):
        for member_idx, bs in enumerate(batch_sizes):
            all_batch_times.append((bs, timer.metrics['member_times'][epoch_idx][member_idx]))

    batch_sizes_scatter = [bt[0] for bt in all_batch_times]
    times_scatter = [bt[1] for bt in all_batch_times]

    scatter = axes[1, 0].scatter(batch_sizes_scatter, times_scatter,
                                alpha=0.6, s=50, c='purple')
    axes[1, 0].set_xlabel('Batch Size', fontsize=12)
    axes[1, 0].set_ylabel('Training Time (seconds)', fontsize=12)
    axes[1, 0].set_title('Batch Size vs Training Time (All Samples)', fontsize=14, fontweight='bold')
    axes[1, 0].set_xticks([64, 128, 256])
    axes[1, 0].grid(True, alpha=0.3)

    # Plot 4: Update time when it occurs
    update_epochs = [i+1 for i, t in enumerate(timer.metrics['update_times']) if t > 0]
    update_times_nonzero = [t for t in timer.metrics['update_times'] if t > 0]

    if update_times_nonzero:
        bars = axes[1, 1].bar(update_epochs, update_times_nonzero, color='orange', alpha=0.7)
        axes[1, 1].set_xlabel('Epoch', fontsize=12)
        axes[1, 1].set_ylabel('Update Time (seconds)', fontsize=12)
        axes[1, 1].set_title('Population Update Times', fontsize=14, fontweight='bold')
        axes[1, 1].set_xticks(update_epochs)
        axes[1, 1].grid(True, alpha=0.3, axis='y')

        # Add value labels
        for bar in bars:
            height = bar.get_height()
            axes[1, 1].text(bar.get_x() + bar.get_width()/2., height,
                           f'{height:.2f}s', ha='center', va='bottom', fontsize=9)
    else:
        axes[1, 1].text(0.5, 0.5, 'No population updates occurred',
                       ha='center', va='center', fontsize=12, transform=axes[1, 1].transAxes)
        axes[1, 1].set_title('Population Update Times', fontsize=14, fontweight='bold')

    plt.suptitle('Detailed Timing Analysis', fontsize=16, fontweight='bold', y=1.02)
    plt.tight_layout()
    plt.savefig('pbt_detailed_timing.png', dpi=300, bbox_inches='tight')
    plt.show()

def plot_detailed_lr_evolution(population, timer, history):
    """Create detailed LR evolution plot showing all changes"""
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10))

    # Plot 1: Individual member LR evolution
    colors = plt.cm.Set3(np.linspace(0, 1, len(population)))

    for i, member in enumerate(population):
        if len(member.lr_history) > 0:
            epochs = range(1, len(member.lr_history) + 1)

            # Plot line
            ax1.semilogy(epochs, member.lr_history,
                        color=colors[i], linewidth=2,
                        label=f'M{i} (BS={member.batch_size})',
                        alpha=0.8)

            # Mark PBT update points (where LR might jump)
            for epoch_idx, lr in enumerate(member.lr_history):
                if epoch_idx > 0 and member.lr_history[epoch_idx-1] != lr:
                    # Check if this was a PBT update epoch
                    if (epoch_idx + 1) in [ep+1 for ep, t in enumerate(timer.metrics['update_times']) if t > 0]:
                        ax1.plot(epoch_idx + 1, lr, 'r*', markersize=10, markeredgewidth=1, markeredgecolor='black')
                    else:
                        ax1.plot(epoch_idx + 1, lr, 'ko', markersize=5, alpha=0.5)

    ax1.set_xlabel('Epoch', fontsize=12)
    ax1.set_ylabel('Learning Rate', fontsize=12)
    ax1.set_title('Detailed Learning Rate Evolution with Changes Marked',
                 fontsize=14, fontweight='bold')
    ax1.legend(fontsize=10, ncol=2, loc='upper right')
    ax1.grid(True, alpha=0.3)

    # Add explanation
    ax1.text(0.02, 0.02, 'Red stars: PBT updates\nBlack dots: Cosine annealing',
            transform=ax1.transAxes, fontsize=10,
            bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

    # Plot 2: LR distribution over time (box plot per epoch)
    max_epochs = max([len(m.lr_history) for m in population if len(m.lr_history) > 0])

    if max_epochs > 0:
        # Collect LRs per epoch
        lrs_per_epoch = []
        for epoch in range(max_epochs):
            epoch_lrs = []
            for member in population:
                if len(member.lr_history) > epoch:
                    epoch_lrs.append(member.lr_history[epoch])
            lrs_per_epoch.append(epoch_lrs)

        # Create box plot
        positions = range(1, max_epochs + 1)
        box_data = [np.log10(np.array(epoch_lrs)) for epoch_lrs in lrs_per_epoch]

        bp = ax2.boxplot(box_data, positions=positions, widths=0.6,
                        patch_artist=True, showfliers=False)

        # Color boxes
        for patch in bp['boxes']:
            patch.set_facecolor('lightblue')
            patch.set_alpha(0.7)

        ax2.set_xlabel('Epoch', fontsize=12)
        ax2.set_ylabel('log10(Learning Rate)', fontsize=12)
        ax2.set_title('Population Learning Rate Distribution Over Time',
                     fontsize=14, fontweight='bold')
        ax2.grid(True, alpha=0.3)

        # Mark PBT update epochs
        for update_epoch in [ep+1 for ep, t in enumerate(timer.metrics['update_times']) if t > 0]:
            if update_epoch <= max_epochs:
                ax2.axvline(x=update_epoch, color='red', alpha=0.5,
                           linestyle='--', linewidth=1)

    plt.tight_layout()
    plt.savefig('pbt_lr_evolution_detailed.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
# ---------------------------
# Main Execution
# ---------------------------

if __name__ == "__main__":
    print("Starting PBT ViT Experiment with Timing...")
    print("Note: This will train ViT-Small models on CIFAR-10")
    print("Each member may have different batch sizes\n")

    pbt, history, timer = run_pbt_vit_experiment()

    print("\nExperiment completed successfully!")
    print(f"Results saved to: pbt_vit_timing_results.png")
    print(f"Detailed timing saved to: pbt_detailed_timing.png")
# Out:
# Starting PBT ViT Experiment with Timing...
# Note: This will train ViT-Small models on CIFAR-10
# Each member may have different batch sizes
#
# Using device: cuda
# Starting PBT Training for ViT-Small...
# Population size: 2
# Total epochs: 60
# Exploit interval: 5 epochs
#
# ============================================================
# Epoch 1/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# 100%|██████████| 170M/170M [00:02<00:00, 64.9MB/s]
# built data in 6.819522857666016 seconds
#  LR changed during epoch: 6.92e-07 -> 1.36e-04
# total runtime to train this model was 54.856929302215576 seconds
# evaluation in 12.173327445983887 seconds
#   Loss: 1.8934
#   Train Accuracy: 29.05%
#   Test Accuracy: 36.09%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.5429348945617676 seconds
#  LR changed during epoch: 1.49e-07 -> 1.16e-04
# total runtime to train this model was 68.86585521697998 seconds
# evaluation in 12.711182355880737 seconds
#   Loss: 1.8458
#   Train Accuracy: 30.93%
#   Test Accuracy: 38.00%
#
# ============================================================
# Epoch 1 Summary:
# ============================================================
# Time: 156.97s (Avg member: 78.49s)
# Population Mean Accuracy: 37.05%
# Best Member Accuracy: 38.00%
# Mean Batch Size: 160
# Mean Learning Rate: 6.29e-04
# Mean Weight Decay: 0.291
#
# ============================================================
# Epoch 2/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5335214138031006 seconds
#  LR changed during epoch: 1.36e-04 -> 2.72e-04
# total runtime to train this model was 63.524375438690186 seconds
# evaluation in 12.903346538543701 seconds
#   Loss: 1.6120
#   Train Accuracy: 40.66%
#   Test Accuracy: 44.23%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.5661506652832031 seconds
#  LR changed during epoch: 1.16e-04 -> 2.32e-04
# total runtime to train this model was 68.37016534805298 seconds
# evaluation in 13.043558835983276 seconds
#   Loss: 1.5213
#   Train Accuracy: 43.99%
#   Test Accuracy: 48.49%
#
# ============================================================
# Epoch 2 Summary:
# ============================================================
# Time: 160.94s (Avg member: 80.47s)
# Population Mean Accuracy: 46.36%
# Best Member Accuracy: 48.49%
# Mean Batch Size: 160
# Mean Learning Rate: 6.29e-04
# Mean Weight Decay: 0.291
#
# ============================================================
# Epoch 3/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5918078422546387 seconds
#  LR changed during epoch: 2.72e-04 -> 4.08e-04
# total runtime to train this model was 63.481579065322876 seconds
# evaluation in 13.028422594070435 seconds
#   Loss: 1.3936
#   Train Accuracy: 49.14%
#   Test Accuracy: 48.05%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.5717663764953613 seconds
#  LR changed during epoch: 2.32e-04 -> 3.49e-04
# total runtime to train this model was 68.48636102676392 seconds
# evaluation in 13.061156749725342 seconds
#   Loss: 1.3909
#   Train Accuracy: 49.49%
#   Test Accuracy: 51.54%
#
# ============================================================
# Epoch 3 Summary:
# ============================================================
# Time: 161.22s (Avg member: 80.61s)
# Population Mean Accuracy: 49.80%
# Best Member Accuracy: 51.54%
# Mean Batch Size: 160
# Mean Learning Rate: 6.29e-04
# Mean Weight Decay: 0.291
#
# ============================================================
# Epoch 4/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5867919921875 seconds
#  LR changed during epoch: 4.08e-04 -> 5.43e-04
# total runtime to train this model was 63.37299346923828 seconds
# evaluation in 12.977200031280518 seconds
#   Loss: 1.2994
#   Train Accuracy: 53.02%
#   Test Accuracy: 55.25%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.5737888813018799 seconds
#  LR changed during epoch: 3.49e-04 -> 4.65e-04
# total runtime to train this model was 68.20358657836914 seconds
# evaluation in 13.122290849685669 seconds
#   Loss: 1.3534
#   Train Accuracy: 50.84%
#   Test Accuracy: 50.53%
#
# ============================================================
# Epoch 4 Summary:
# ============================================================
# Time: 160.84s (Avg member: 80.42s)
# Population Mean Accuracy: 52.89%
# Best Member Accuracy: 55.25%
# Mean Batch Size: 160
# Mean Learning Rate: 6.29e-04
# Mean Weight Decay: 0.291
#
# ============================================================
# Epoch 5/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.584519386291504 seconds
#  LR changed during epoch: 5.43e-04 -> 6.78e-04
# total runtime to train this model was 63.163955211639404 seconds
# evaluation in 12.924289226531982 seconds
#   Loss: 1.2492
#   Train Accuracy: 54.67%
#   Test Accuracy: 55.54%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.58695387840271 seconds
#  LR changed during epoch: 4.65e-04 -> 5.81e-04
# total runtime to train this model was 68.2088725566864 seconds
# evaluation in 13.10411024093628 seconds
#   Loss: 1.3298
#   Train Accuracy: 51.93%
#   Test Accuracy: 52.43%
#
# --- Population Update (Epoch 5) ---
#
# === PBT Exploit & Explore ===
# Truncating 1 members
# Top performers: ['55.54%']
# Bottom performers: ['52.43%']
# Member 1: lr changed from 0.0005807349503458951 to 0.0008438282300725348
# Member 1: weight_decay changed from 0.28407530761646993 to 0.25353341154057296
# Member 1: drop_path changed from 0.18764955380182036 to 0.15738846802964482
# Member 1 copied from 0
#   LR=8.44e-04, WD=0.254, DropPath=0.157, Warmup=5 epochs, Batch=64
#
# ============================================================
# Epoch 5 Summary:
# ============================================================
# Time: 160.58s (Avg member: 80.29s)
# Population Mean Accuracy: 53.98%
# Best Member Accuracy: 55.54%
# Mean Batch Size: 160
# Mean Learning Rate: 7.61e-04
# Mean Weight Decay: 0.276
#
# ============================================================
# Epoch 6/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5927512645721436 seconds
#  LR changed during epoch: 6.78e-04 -> 6.78e-04
# total runtime to train this model was 63.42136526107788 seconds
# evaluation in 12.982235193252563 seconds
#   Loss: 1.2136
#   Train Accuracy: 56.28%
#   Test Accuracy: 58.50%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.5737504959106445 seconds
#  LR changed during epoch: 2.16e-07 -> 1.69e-04
# total runtime to train this model was 68.02096652984619 seconds
# evaluation in 13.034468650817871 seconds
#   Loss: 1.1102
#   Train Accuracy: 59.96%
#   Test Accuracy: 61.34%
#
# ============================================================
# Epoch 6 Summary:
# ============================================================
# Time: 160.63s (Avg member: 80.31s)
# Population Mean Accuracy: 59.92%
# Best Member Accuracy: 61.34%
# Mean Batch Size: 160
# Mean Learning Rate: 7.61e-04
# Mean Weight Decay: 0.276
#
# ============================================================
# Epoch 7/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5865263938903809 seconds
#  LR changed during epoch: 6.78e-04 -> 6.76e-04
# total runtime to train this model was 63.508084297180176 seconds
# evaluation in 13.039465188980103 seconds
#   Loss: 1.1521
#   Train Accuracy: 58.55%
#   Test Accuracy: 59.82%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.566542625427246 seconds
#  LR changed during epoch: 1.69e-04 -> 3.38e-04
# total runtime to train this model was 68.06663513183594 seconds
# evaluation in 13.021576642990112 seconds
#   Loss: 1.1734
#   Train Accuracy: 57.89%
#   Test Accuracy: 55.31%
#
# ============================================================
# Epoch 7 Summary:
# ============================================================
# Time: 160.79s (Avg member: 80.40s)
# Population Mean Accuracy: 57.56%
# Best Member Accuracy: 59.82%
# Mean Batch Size: 160
# Mean Learning Rate: 7.61e-04
# Mean Weight Decay: 0.276
#
# ============================================================
# Epoch 8/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5850181579589844 seconds
#  LR changed during epoch: 6.76e-04 -> 6.73e-04
# total runtime to train this model was 63.52109670639038 seconds
# evaluation in 13.02514934539795 seconds
#   Loss: 1.1004
#   Train Accuracy: 60.49%
#   Test Accuracy: 60.41%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.5693199634552002 seconds
#  LR changed during epoch: 3.38e-04 -> 5.07e-04
# total runtime to train this model was 67.92125177383423 seconds
# evaluation in 13.017426490783691 seconds
#   Loss: 1.2116
#   Train Accuracy: 56.54%
#   Test Accuracy: 58.25%
#
# ============================================================
# Epoch 8 Summary:
# ============================================================
# Time: 160.64s (Avg member: 80.32s)
# Population Mean Accuracy: 59.33%
# Best Member Accuracy: 60.41%
# Mean Batch Size: 160
# Mean Learning Rate: 7.61e-04
# Mean Weight Decay: 0.276
#
# ============================================================
# Epoch 9/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5849223136901855 seconds
#  LR changed during epoch: 6.73e-04 -> 6.69e-04
# total runtime to train this model was 63.5602171421051 seconds
# evaluation in 13.031395196914673 seconds
#   Loss: 1.0578
#   Train Accuracy: 62.18%
#   Test Accuracy: 64.10%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.5822803974151611 seconds
#  LR changed during epoch: 5.07e-04 -> 6.75e-04
# total runtime to train this model was 68.07207417488098 seconds
# evaluation in 12.958400249481201 seconds
#   Loss: 1.1961
#   Train Accuracy: 57.10%
#   Test Accuracy: 56.22%
#
# ============================================================
# Epoch 9 Summary:
# ============================================================
# Time: 160.79s (Avg member: 80.40s)
# Population Mean Accuracy: 60.16%
# Best Member Accuracy: 64.10%
# Mean Batch Size: 160
# Mean Learning Rate: 7.61e-04
# Mean Weight Decay: 0.276
#
# ============================================================
# Epoch 10/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5925848484039307 seconds
#  LR changed during epoch: 6.69e-04 -> 6.64e-04
# total runtime to train this model was 63.46605038642883 seconds
# evaluation in 13.07598066329956 seconds
#   Loss: 0.9978
#   Train Accuracy: 64.30%
#   Test Accuracy: 65.28%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.5775260925292969 seconds
#  LR changed during epoch: 6.75e-04 -> 8.44e-04
# total runtime to train this model was 68.1763916015625 seconds
# evaluation in 12.999722242355347 seconds
#   Loss: 1.1813
#   Train Accuracy: 57.62%
#   Test Accuracy: 61.07%
#
# --- Population Update (Epoch 10) ---
#
# === PBT Exploit & Explore ===
# Truncating 1 members
# Top performers: ['65.28%']
# Bottom performers: ['61.07%']
# Member 1: lr changed from 0.0008438282300725348 to 0.0008660017422215446
# Member 1: weight_decay changed from 0.25353341154057296 to 0.2801216871417854
# Member 1: drop_path changed from 0.15738846802964482 to 0.1474288466851825
# Member 1 copied from 0
#   LR=8.66e-04, WD=0.280, DropPath=0.147, Warmup=5 epochs, Batch=64
#
# ============================================================
# Epoch 10 Summary:
# ============================================================
# Time: 160.90s (Avg member: 80.45s)
# Population Mean Accuracy: 63.17%
# Best Member Accuracy: 65.28%
# Mean Batch Size: 160
# Mean Learning Rate: 7.72e-04
# Mean Weight Decay: 0.289
#
# ============================================================
# Epoch 11/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.6074473857879639 seconds
#  LR changed during epoch: 6.64e-04 -> 6.59e-04
# total runtime to train this model was 63.39445447921753 seconds
# evaluation in 12.989246606826782 seconds
#   Loss: 0.9710
#   Train Accuracy: 65.34%
#   Test Accuracy: 66.37%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.570626974105835 seconds
#  LR changed during epoch: 2.21e-07 -> 1.73e-04
# total runtime to train this model was 67.77123999595642 seconds
# evaluation in 12.998173236846924 seconds
#   Loss: 0.8928
#   Train Accuracy: 68.41%
#   Test Accuracy: 68.22%
#
# ============================================================
# Epoch 11 Summary:
# ============================================================
# Time: 160.33s (Avg member: 80.17s)
# Population Mean Accuracy: 67.30%
# Best Member Accuracy: 68.22%
# Mean Batch Size: 160
# Mean Learning Rate: 7.72e-04
# Mean Weight Decay: 0.289
#
# ============================================================
# Epoch 12/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5890254974365234 seconds
#  LR changed during epoch: 6.59e-04 -> 6.51e-04
# total runtime to train this model was 63.33742666244507 seconds
# evaluation in 13.064919710159302 seconds
#   Loss: 0.9217
#   Train Accuracy: 67.10%
#   Test Accuracy: 67.97%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.5788533687591553 seconds
#  LR changed during epoch: 1.73e-04 -> 3.47e-04
# total runtime to train this model was 68.46240854263306 seconds
# evaluation in 13.09906268119812 seconds
#   Loss: 0.9660
#   Train Accuracy: 65.71%
#   Test Accuracy: 65.10%
#
# ============================================================
# Epoch 12 Summary:
# ============================================================
# Time: 161.13s (Avg member: 80.57s)
# Population Mean Accuracy: 66.53%
# Best Member Accuracy: 67.97%
# Mean Batch Size: 160
# Mean Learning Rate: 7.72e-04
# Mean Weight Decay: 0.289
#
# ============================================================
# Epoch 13/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5808558464050293 seconds
#  LR changed during epoch: 6.51e-04 -> 6.43e-04
# total runtime to train this model was 63.66239142417908 seconds
# evaluation in 13.086363554000854 seconds
#   Loss: 0.8838
#   Train Accuracy: 68.61%
#   Test Accuracy: 69.62%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.576768159866333 seconds
#  LR changed during epoch: 3.47e-04 -> 5.20e-04
# total runtime to train this model was 68.08072590827942 seconds
# evaluation in 12.980024814605713 seconds
#   Loss: 1.0107
#   Train Accuracy: 64.15%
#   Test Accuracy: 62.72%
#
# ============================================================
# Epoch 13 Summary:
# ============================================================
# Time: 160.97s (Avg member: 80.48s)
# Population Mean Accuracy: 66.17%
# Best Member Accuracy: 69.62%
# Mean Batch Size: 160
# Mean Learning Rate: 7.72e-04
# Mean Weight Decay: 0.289
#
# ============================================================
# Epoch 14/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.6127243041992188 seconds
#  LR changed during epoch: 6.43e-04 -> 6.34e-04
# total runtime to train this model was 63.55598282814026 seconds
# evaluation in 13.045393466949463 seconds
#   Loss: 0.8517
#   Train Accuracy: 69.78%
#   Test Accuracy: 69.40%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.5770366191864014 seconds
#  LR changed during epoch: 5.20e-04 -> 6.93e-04
# total runtime to train this model was 68.41720151901245 seconds
# evaluation in 13.090813875198364 seconds
#   Loss: 1.0454
#   Train Accuracy: 62.98%
#   Test Accuracy: 60.95%
#
# ============================================================
# Epoch 14 Summary:
# ============================================================
# Time: 161.30s (Avg member: 80.65s)
# Population Mean Accuracy: 65.18%
# Best Member Accuracy: 69.40%
# Mean Batch Size: 160
# Mean Learning Rate: 7.72e-04
# Mean Weight Decay: 0.289
#
# ============================================================
# Epoch 15/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5901062488555908 seconds
#  LR changed during epoch: 6.34e-04 -> 6.24e-04
# total runtime to train this model was 63.4341983795166 seconds
# evaluation in 13.04146695137024 seconds
#   Loss: 0.8259
#   Train Accuracy: 70.93%
#   Test Accuracy: 71.28%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.5752899646759033 seconds
#  LR changed during epoch: 6.93e-04 -> 8.66e-04
# total runtime to train this model was 68.48616147041321 seconds
# evaluation in 12.938676595687866 seconds
#   Loss: 1.0550
#   Train Accuracy: 62.68%
#   Test Accuracy: 63.09%
#
# --- Population Update (Epoch 15) ---
#
# === PBT Exploit & Explore ===
# Truncating 1 members
# Top performers: ['71.28%']
# Bottom performers: ['63.09%']
# Member 1: lr changed from 0.0008660017422215446 to 0.0007999878654499531
# Member 1: weight_decay changed from 0.2801216871417854 to 0.26666955891568184
# Member 1: drop_path changed from 0.1474288466851825 to 0.16472913002377448
# Member 1 copied from 0
#   LR=8.00e-04, WD=0.267, DropPath=0.165, Warmup=5 epochs, Batch=64
#
# ============================================================
# Epoch 15 Summary:
# ============================================================
# Time: 161.08s (Avg member: 80.53s)
# Population Mean Accuracy: 67.19%
# Best Member Accuracy: 71.28%
# Mean Batch Size: 160
# Mean Learning Rate: 7.39e-04
# Mean Weight Decay: 0.282
#
# ============================================================
# Epoch 16/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5968554019927979 seconds
#  LR changed during epoch: 6.24e-04 -> 6.14e-04
# total runtime to train this model was 63.57464027404785 seconds
# evaluation in 13.034241437911987 seconds
#   Loss: 0.7841
#   Train Accuracy: 72.27%
#   Test Accuracy: 70.13%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.6050186157226562 seconds
#  LR changed during epoch: 2.05e-07 -> 1.60e-04
# total runtime to train this model was 67.8013379573822 seconds
# evaluation in 12.922013998031616 seconds
#   Loss: 0.7184
#   Train Accuracy: 74.48%
#   Test Accuracy: 73.63%
#
# ============================================================
# Epoch 16 Summary:
# ============================================================
# Time: 160.54s (Avg member: 80.27s)
# Population Mean Accuracy: 71.88%
# Best Member Accuracy: 73.63%
# Mean Batch Size: 160
# Mean Learning Rate: 7.39e-04
# Mean Weight Decay: 0.282
#
# ============================================================
# Epoch 17/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.588747262954712 seconds
#  LR changed during epoch: 6.14e-04 -> 6.02e-04
# total runtime to train this model was 63.69131851196289 seconds
# evaluation in 12.928180932998657 seconds
#   Loss: 0.7620
#   Train Accuracy: 73.27%
#   Test Accuracy: 73.66%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.5787935256958008 seconds
#  LR changed during epoch: 1.60e-04 -> 3.20e-04
# total runtime to train this model was 68.34864354133606 seconds
# evaluation in 13.096451997756958 seconds
#   Loss: 0.7794
#   Train Accuracy: 72.40%
#   Test Accuracy: 72.88%
#
# ============================================================
# Epoch 17 Summary:
# ============================================================
# Time: 161.23s (Avg member: 80.62s)
# Population Mean Accuracy: 73.27%
# Best Member Accuracy: 73.66%
# Mean Batch Size: 160
# Mean Learning Rate: 7.39e-04
# Mean Weight Decay: 0.282
#
# ============================================================
# Epoch 18/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5858635902404785 seconds
#  LR changed during epoch: 6.02e-04 -> 5.89e-04
# total runtime to train this model was 63.43747329711914 seconds
# evaluation in 12.950034618377686 seconds
#   Loss: 0.7299
#   Train Accuracy: 74.25%
#   Test Accuracy: 73.00%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.5831995010375977 seconds
#  LR changed during epoch: 3.20e-04 -> 4.80e-04
# total runtime to train this model was 68.26459264755249 seconds
# evaluation in 13.1073317527771 seconds
#   Loss: 0.8585
#   Train Accuracy: 69.70%
#   Test Accuracy: 66.15%
#
# ============================================================
# Epoch 18 Summary:
# ============================================================
# Time: 160.93s (Avg member: 80.47s)
# Population Mean Accuracy: 69.58%
# Best Member Accuracy: 73.00%
# Mean Batch Size: 160
# Mean Learning Rate: 7.39e-04
# Mean Weight Decay: 0.282
#
# ============================================================
# Epoch 19/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5830848217010498 seconds
#  LR changed during epoch: 5.89e-04 -> 5.76e-04
# total runtime to train this model was 63.412028074264526 seconds
# evaluation in 12.926458358764648 seconds
#   Loss: 0.7093
#   Train Accuracy: 74.99%
#   Test Accuracy: 75.49%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.569455623626709 seconds
#  LR changed during epoch: 4.80e-04 -> 6.40e-04
# total runtime to train this model was 68.3296549320221 seconds
# evaluation in 13.060791492462158 seconds
#   Loss: 0.9103
#   Train Accuracy: 67.80%
#   Test Accuracy: 67.74%
#
# ============================================================
# Epoch 19 Summary:
# ============================================================
# Time: 160.88s (Avg member: 80.44s)
# Population Mean Accuracy: 71.61%
# Best Member Accuracy: 75.49%
# Mean Batch Size: 160
# Mean Learning Rate: 7.39e-04
# Mean Weight Decay: 0.282
#
# ============================================================
# Epoch 20/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5864653587341309 seconds
#  LR changed during epoch: 5.76e-04 -> 5.61e-04
# total runtime to train this model was 63.39305925369263 seconds
# evaluation in 12.95657205581665 seconds
#   Loss: 0.6912
#   Train Accuracy: 75.73%
#   Test Accuracy: 74.93%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.5792779922485352 seconds
#  LR changed during epoch: 6.40e-04 -> 8.00e-04
# total runtime to train this model was 68.45913529396057 seconds
# evaluation in 13.048887491226196 seconds
#   Loss: 0.9457
#   Train Accuracy: 66.70%
#   Test Accuracy: 65.96%
#
# --- Population Update (Epoch 20) ---
#
# === PBT Exploit & Explore ===
# Truncating 1 members
# Top performers: ['74.93%']
# Bottom performers: ['65.96%']
# Member 1: lr changed from 0.0007999878654499531 to 0.0005168397182036138
# Member 1: weight_decay changed from 0.26666955891568184 to 0.2739308046870628
# Member 1: drop_path changed from 0.16472913002377448 to 0.1304415436222468
# Member 1 copied from 0
#   LR=5.17e-04, WD=0.274, DropPath=0.130, Warmup=5 epochs, Batch=64
#
# ============================================================
# Epoch 20 Summary:
# ============================================================
# Time: 161.03s (Avg member: 80.51s)
# Population Mean Accuracy: 70.44%
# Best Member Accuracy: 74.93%
# Mean Batch Size: 160
# Mean Learning Rate: 5.98e-04
# Mean Weight Decay: 0.286
#
# ============================================================
# Epoch 21/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5833079814910889 seconds
#  LR changed during epoch: 5.61e-04 -> 5.46e-04
# total runtime to train this model was 63.68331837654114 seconds
# evaluation in 13.104496240615845 seconds
#   Loss: 0.6701
#   Train Accuracy: 76.25%
#   Test Accuracy: 76.27%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.576507568359375 seconds
#  LR changed during epoch: 1.32e-07 -> 1.04e-04
# total runtime to train this model was 67.98220729827881 seconds
# evaluation in 12.894928216934204 seconds
#   Loss: 0.5815
#   Train Accuracy: 79.45%
#   Test Accuracy: 78.27%
#
# ============================================================
# Epoch 21 Summary:
# ============================================================
# Time: 160.83s (Avg member: 80.41s)
# Population Mean Accuracy: 77.27%
# Best Member Accuracy: 78.27%
# Mean Batch Size: 160
# Mean Learning Rate: 5.98e-04
# Mean Weight Decay: 0.286
#
# ============================================================
# Epoch 22/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.584045648574829 seconds
#  LR changed during epoch: 5.46e-04 -> 5.31e-04
# total runtime to train this model was 63.64971303939819 seconds
# evaluation in 13.017053604125977 seconds
#   Loss: 0.6414
#   Train Accuracy: 77.52%
#   Test Accuracy: 76.99%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.5684120655059814 seconds
#  LR changed during epoch: 1.04e-04 -> 2.07e-04
# total runtime to train this model was 67.89969325065613 seconds
# evaluation in 12.9213547706604 seconds
#   Loss: 0.6135
#   Train Accuracy: 78.58%
#   Test Accuracy: 76.16%
#
# ============================================================
# Epoch 22 Summary:
# ============================================================
# Time: 160.64s (Avg member: 80.32s)
# Population Mean Accuracy: 76.57%
# Best Member Accuracy: 76.99%
# Mean Batch Size: 160
# Mean Learning Rate: 5.98e-04
# Mean Weight Decay: 0.286
#
# ============================================================
# Epoch 23/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5816724300384521 seconds
#  LR changed during epoch: 5.31e-04 -> 5.14e-04
# total runtime to train this model was 63.528558015823364 seconds
# evaluation in 13.101611614227295 seconds
#   Loss: 0.6252
#   Train Accuracy: 77.91%
#   Test Accuracy: 76.32%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.5731868743896484 seconds
#  LR changed during epoch: 2.07e-04 -> 3.10e-04
# total runtime to train this model was 68.23537278175354 seconds
# evaluation in 12.995532751083374 seconds
#   Loss: 0.6763
#   Train Accuracy: 75.95%
#   Test Accuracy: 73.82%
#
# ============================================================
# Epoch 23 Summary:
# ============================================================
# Time: 161.02s (Avg member: 80.51s)
# Population Mean Accuracy: 75.07%
# Best Member Accuracy: 76.32%
# Mean Batch Size: 160
# Mean Learning Rate: 5.98e-04
# Mean Weight Decay: 0.286
#
# ============================================================
# Epoch 24/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.592092752456665 seconds
#  LR changed during epoch: 5.14e-04 -> 4.98e-04
# total runtime to train this model was 63.68283200263977 seconds
# evaluation in 13.056718587875366 seconds
#   Loss: 0.6111
#   Train Accuracy: 78.39%
#   Test Accuracy: 78.16%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.5756919384002686 seconds
#  LR changed during epoch: 3.10e-04 -> 4.14e-04
# total runtime to train this model was 68.18403005599976 seconds
# evaluation in 12.984669923782349 seconds
#   Loss: 0.7402
#   Train Accuracy: 74.19%
#   Test Accuracy: 73.96%
#
# ============================================================
# Epoch 24 Summary:
# ============================================================
# Time: 161.08s (Avg member: 80.54s)
# Population Mean Accuracy: 76.06%
# Best Member Accuracy: 78.16%
# Mean Batch Size: 160
# Mean Learning Rate: 5.98e-04
# Mean Weight Decay: 0.286
#
# ============================================================
# Epoch 25/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.599133014678955 seconds
#  LR changed during epoch: 4.98e-04 -> 4.80e-04
# total runtime to train this model was 63.41959476470947 seconds
# evaluation in 13.026830911636353 seconds
#   Loss: 0.5920
#   Train Accuracy: 79.07%
#   Test Accuracy: 78.68%
#
# --- Training Member 1 (Batch size: 64) ---
# built data in 1.5749928951263428 seconds
#  LR changed during epoch: 4.14e-04 -> 5.17e-04
# total runtime to train this model was 68.54698967933655 seconds
# evaluation in 13.085272550582886 seconds
#   Loss: 0.7811
#   Train Accuracy: 72.56%
#   Test Accuracy: 68.87%
#
# --- Population Update (Epoch 25) ---
#
# === PBT Exploit & Explore ===
# Truncating 1 members
# Top performers: ['78.68%']
# Bottom performers: ['68.87%']
# Member 1: lr changed from 0.0005168397182036138 to 0.0005245458927208258
# Member 1: weight_decay changed from 0.2739308046870628 to 0.24809145108274025
# Member 1: drop_path changed from 0.1304415436222468 to 0.10286874154484403
# Member 1: batch_size changed from 64 to 128
# Member 1 copied from 0
#   LR=5.25e-04, WD=0.248, DropPath=0.103, Warmup=5 epochs, Batch=128
#
# ============================================================
# Epoch 25 Summary:
# ============================================================
# Time: 161.26s (Avg member: 80.63s)
# Population Mean Accuracy: 73.78%
# Best Member Accuracy: 78.68%
# Mean Batch Size: 192
# Mean Learning Rate: 6.01e-04
# Mean Weight Decay: 0.273
#
# ============================================================
# Epoch 26/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5863215923309326 seconds
#  LR changed during epoch: 4.80e-04 -> 4.62e-04
# total runtime to train this model was 63.68242359161377 seconds
# evaluation in 13.047010660171509 seconds
#   Loss: 0.5604
#   Train Accuracy: 80.23%
#   Test Accuracy: 78.04%
#
# --- Training Member 1 (Batch size: 128) ---
# built data in 1.592878818511963 seconds
#  LR changed during epoch: 2.68e-07 -> 1.05e-04
# total runtime to train this model was 65.24651503562927 seconds
# evaluation in 13.06317138671875 seconds
#   Loss: 0.4859
#   Train Accuracy: 82.99%
#   Test Accuracy: 81.10%
#
# ============================================================
# Epoch 26 Summary:
# ============================================================
# Time: 158.22s (Avg member: 79.11s)
# Population Mean Accuracy: 79.57%
# Best Member Accuracy: 81.10%
# Mean Batch Size: 192
# Mean Learning Rate: 6.01e-04
# Mean Weight Decay: 0.273
#
# ============================================================
# Epoch 27/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5968151092529297 seconds
#  LR changed during epoch: 4.62e-04 -> 4.44e-04
# total runtime to train this model was 63.82891821861267 seconds
# evaluation in 13.063016891479492 seconds
#   Loss: 0.5488
#   Train Accuracy: 80.66%
#   Test Accuracy: 79.56%
#
# --- Training Member 1 (Batch size: 128) ---
# built data in 1.5774734020233154 seconds
#  LR changed during epoch: 1.05e-04 -> 2.10e-04
# total runtime to train this model was 65.22728204727173 seconds
# evaluation in 13.077718019485474 seconds
#   Loss: 0.4948
#   Train Accuracy: 82.77%
#   Test Accuracy: 78.99%
#
# ============================================================
# Epoch 27 Summary:
# ============================================================
# Time: 158.37s (Avg member: 79.19s)
# Population Mean Accuracy: 79.28%
# Best Member Accuracy: 79.56%
# Mean Batch Size: 192
# Mean Learning Rate: 6.01e-04
# Mean Weight Decay: 0.273
#
# ============================================================
# Epoch 28/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5833899974822998 seconds
#  LR changed during epoch: 4.44e-04 -> 4.26e-04
# total runtime to train this model was 63.866567850112915 seconds
# evaluation in 13.040521621704102 seconds
#   Loss: 0.5318
#   Train Accuracy: 81.32%
#   Test Accuracy: 80.50%
#
# --- Training Member 1 (Batch size: 128) ---
# built data in 1.5830788612365723 seconds
#  LR changed during epoch: 2.10e-04 -> 3.15e-04
# total runtime to train this model was 65.14357948303223 seconds
# evaluation in 13.113834619522095 seconds
#   Loss: 0.5442
#   Train Accuracy: 80.75%
#   Test Accuracy: 78.79%
#
# ============================================================
# Epoch 28 Summary:
# ============================================================
# Time: 158.33s (Avg member: 79.17s)
# Population Mean Accuracy: 79.65%
# Best Member Accuracy: 80.50%
# Mean Batch Size: 192
# Mean Learning Rate: 6.01e-04
# Mean Weight Decay: 0.273
#
# ============================================================
# Epoch 29/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5877883434295654 seconds
#  LR changed during epoch: 4.26e-04 -> 4.07e-04
# total runtime to train this model was 63.255985498428345 seconds
# evaluation in 12.947723388671875 seconds
#   Loss: 0.5123
#   Train Accuracy: 81.87%
#   Test Accuracy: 80.79%
#
# --- Training Member 1 (Batch size: 128) ---
# built data in 1.571491003036499 seconds
#  LR changed during epoch: 3.15e-04 -> 4.20e-04
# total runtime to train this model was 64.92816877365112 seconds
# evaluation in 13.099401950836182 seconds
#   Loss: 0.5880
#   Train Accuracy: 79.26%
#   Test Accuracy: 76.68%
#
# ============================================================
# Epoch 29 Summary:
# ============================================================
# Time: 157.39s (Avg member: 78.70s)
# Population Mean Accuracy: 78.74%
# Best Member Accuracy: 80.79%
# Mean Batch Size: 192
# Mean Learning Rate: 6.01e-04
# Mean Weight Decay: 0.273
#
# ============================================================
# Epoch 30/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5810110569000244 seconds
#  LR changed during epoch: 4.07e-04 -> 3.88e-04
# total runtime to train this model was 63.41312313079834 seconds
# evaluation in 12.972899913787842 seconds
#   Loss: 0.4947
#   Train Accuracy: 82.54%
#   Test Accuracy: 80.85%
#
# --- Training Member 1 (Batch size: 128) ---
# built data in 1.5709316730499268 seconds
#  LR changed during epoch: 4.20e-04 -> 5.25e-04
# total runtime to train this model was 64.99243521690369 seconds
# evaluation in 13.10443115234375 seconds
#   Loss: 0.6282
#   Train Accuracy: 77.84%
#   Test Accuracy: 77.23%
#
# --- Population Update (Epoch 30) ---
#
# === PBT Exploit & Explore ===
# Truncating 1 members
# Top performers: ['80.85%']
# Bottom performers: ['77.23%']
# Member 1: lr changed from 0.0005245458927208258 to 0.0005114993298178399
# Member 1: weight_decay changed from 0.24809145108274025 to 0.27630041573440717
# Member 1: drop_path changed from 0.10286874154484403 to 0.11565638649468202
# Member 1: batch_size changed from 128 to 256
# Member 1 copied from 0
#   LR=5.11e-04, WD=0.276, DropPath=0.116, Warmup=5 epochs, Batch=256
#
# ============================================================
# Epoch 30 Summary:
# ============================================================
# Time: 157.65s (Avg member: 78.82s)
# Population Mean Accuracy: 79.04%
# Best Member Accuracy: 80.85%
# Mean Batch Size: 256
# Mean Learning Rate: 5.95e-04
# Mean Weight Decay: 0.287
#
# ============================================================
# Epoch 31/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5989530086517334 seconds
#  LR changed during epoch: 3.88e-04 -> 3.68e-04
# total runtime to train this model was 63.31451463699341 seconds
# evaluation in 12.919735431671143 seconds
#   Loss: 0.4745
#   Train Accuracy: 83.30%
#   Test Accuracy: 80.62%
#
# --- Training Member 1 (Batch size: 256) ---
# built data in 1.5891335010528564 seconds
#  LR changed during epoch: 5.22e-07 -> 1.03e-04
# total runtime to train this model was 63.305004835128784 seconds
# evaluation in 13.006764888763428 seconds
#   Loss: 0.4000
#   Train Accuracy: 85.85%
#   Test Accuracy: 82.61%
#
# ============================================================
# Epoch 31 Summary:
# ============================================================
# Time: 155.74s (Avg member: 77.87s)
# Population Mean Accuracy: 81.62%
# Best Member Accuracy: 82.61%
# Mean Batch Size: 256
# Mean Learning Rate: 5.95e-04
# Mean Weight Decay: 0.287
#
# ============================================================
# Epoch 32/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5875353813171387 seconds
#  LR changed during epoch: 3.68e-04 -> 3.49e-04
# total runtime to train this model was 63.341968297958374 seconds
# evaluation in 12.898545503616333 seconds
#   Loss: 0.4573
#   Train Accuracy: 83.78%
#   Test Accuracy: 80.96%
#
# --- Training Member 1 (Batch size: 256) ---
# built data in 1.580129623413086 seconds
#  LR changed during epoch: 1.03e-04 -> 2.05e-04
# total runtime to train this model was 63.374926805496216 seconds
# evaluation in 13.125401496887207 seconds
#   Loss: 0.4038
#   Train Accuracy: 85.75%
#   Test Accuracy: 81.95%
#
# ============================================================
# Epoch 32 Summary:
# ============================================================
# Time: 155.91s (Avg member: 77.96s)
# Population Mean Accuracy: 81.45%
# Best Member Accuracy: 81.95%
# Mean Batch Size: 256
# Mean Learning Rate: 5.95e-04
# Mean Weight Decay: 0.287
#
# ============================================================
# Epoch 33/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.6167902946472168 seconds
#  LR changed during epoch: 3.49e-04 -> 3.30e-04
# total runtime to train this model was 63.84097933769226 seconds
# evaluation in 13.070313930511475 seconds
#   Loss: 0.4406
#   Train Accuracy: 84.51%
#   Test Accuracy: 81.31%
#
# --- Training Member 1 (Batch size: 256) ---
# built data in 1.5888276100158691 seconds
#  LR changed during epoch: 2.05e-04 -> 3.07e-04
# total runtime to train this model was 63.47282934188843 seconds
# evaluation in 13.08247447013855 seconds
#   Loss: 0.4320
#   Train Accuracy: 84.68%
#   Test Accuracy: 81.05%
#
# ============================================================
# Epoch 33 Summary:
# ============================================================
# Time: 156.67s (Avg member: 78.34s)
# Population Mean Accuracy: 81.18%
# Best Member Accuracy: 81.31%
# Mean Batch Size: 256
# Mean Learning Rate: 5.95e-04
# Mean Weight Decay: 0.287
#
# ============================================================
# Epoch 34/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.597137212753296 seconds
#  LR changed during epoch: 3.30e-04 -> 3.11e-04
# total runtime to train this model was 63.63192367553711 seconds
# evaluation in 13.105832576751709 seconds
#   Loss: 0.4226
#   Train Accuracy: 85.15%
#   Test Accuracy: 81.85%
#
# --- Training Member 1 (Batch size: 256) ---
# built data in 1.568446159362793 seconds
#  LR changed during epoch: 3.07e-04 -> 4.10e-04
# total runtime to train this model was 63.189189195632935 seconds
# evaluation in 12.962931156158447 seconds
#   Loss: 0.4620
#   Train Accuracy: 83.77%
#   Test Accuracy: 78.94%
#
# ============================================================
# Epoch 34 Summary:
# ============================================================
# Time: 156.06s (Avg member: 78.03s)
# Population Mean Accuracy: 80.39%
# Best Member Accuracy: 81.85%
# Mean Batch Size: 256
# Mean Learning Rate: 5.95e-04
# Mean Weight Decay: 0.287
#
# ============================================================
# Epoch 35/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5903041362762451 seconds
#  LR changed during epoch: 3.11e-04 -> 2.91e-04
# total runtime to train this model was 63.51980900764465 seconds
# evaluation in 13.097851991653442 seconds
#   Loss: 0.4022
#   Train Accuracy: 85.75%
#   Test Accuracy: 81.19%
#
# --- Training Member 1 (Batch size: 256) ---
# built data in 1.5744152069091797 seconds
#  LR changed during epoch: 4.10e-04 -> 5.11e-04
# total runtime to train this model was 63.38079524040222 seconds
# evaluation in 13.071923017501831 seconds
#   Loss: 0.4995
#   Train Accuracy: 82.45%
#   Test Accuracy: 80.37%
#
# --- Population Update (Epoch 35) ---
#
# === PBT Exploit & Explore ===
# Truncating 1 members
# Top performers: ['81.19%']
# Bottom performers: ['80.37%']
# Member 1: lr changed from 0.0005114993298178399 to 0.00042596476206306166
# Member 1: weight_decay changed from 0.27630041573440717 to 0.25845150695245805
# Member 1: drop_path changed from 0.11565638649468202 to 0.1347297918264889
# Member 1 copied from 0
#   LR=4.26e-04, WD=0.258, DropPath=0.135, Warmup=5 epochs, Batch=256
#
# ============================================================
# Epoch 35 Summary:
# ============================================================
# Time: 156.25s (Avg member: 78.12s)
# Population Mean Accuracy: 80.78%
# Best Member Accuracy: 81.19%
# Mean Batch Size: 256
# Mean Learning Rate: 5.52e-04
# Mean Weight Decay: 0.278
#
# ============================================================
# Epoch 36/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5808496475219727 seconds
#  LR changed during epoch: 2.91e-04 -> 2.72e-04
# total runtime to train this model was 63.946091413497925 seconds
# evaluation in 13.018342733383179 seconds
#   Loss: 0.3854
#   Train Accuracy: 86.32%
#   Test Accuracy: 81.92%
#
# --- Training Member 1 (Batch size: 256) ---
# built data in 1.5715107917785645 seconds
#  LR changed during epoch: 4.35e-07 -> 8.56e-05
# total runtime to train this model was 63.348456621170044 seconds
# evaluation in 13.09723687171936 seconds
#   Loss: 0.3353
#   Train Accuracy: 88.17%
#   Test Accuracy: 83.49%
#
# ============================================================
# Epoch 36 Summary:
# ============================================================
# Time: 156.56s (Avg member: 78.28s)
# Population Mean Accuracy: 82.70%
# Best Member Accuracy: 83.49%
# Mean Batch Size: 256
# Mean Learning Rate: 5.52e-04
# Mean Weight Decay: 0.278
#
# ============================================================
# Epoch 37/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5800869464874268 seconds
#  LR changed during epoch: 2.72e-04 -> 2.53e-04
# total runtime to train this model was 63.945658922195435 seconds
# evaluation in 13.052777767181396 seconds
#   Loss: 0.3653
#   Train Accuracy: 87.13%
#   Test Accuracy: 82.06%
#
# --- Training Member 1 (Batch size: 256) ---
# built data in 1.5994055271148682 seconds
#  LR changed during epoch: 8.56e-05 -> 1.71e-04
# total runtime to train this model was 63.42646408081055 seconds
# evaluation in 13.100767612457275 seconds
#   Loss: 0.3298
#   Train Accuracy: 88.39%
#   Test Accuracy: 82.82%
#
# ============================================================
# Epoch 37 Summary:
# ============================================================
# Time: 156.71s (Avg member: 78.35s)
# Population Mean Accuracy: 82.44%
# Best Member Accuracy: 82.82%
# Mean Batch Size: 256
# Mean Learning Rate: 5.52e-04
# Mean Weight Decay: 0.278
#
# ============================================================
# Epoch 38/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5806467533111572 seconds
#  LR changed during epoch: 2.53e-04 -> 2.35e-04
# total runtime to train this model was 63.68554091453552 seconds
# evaluation in 13.097828388214111 seconds
#   Loss: 0.3524
#   Train Accuracy: 87.42%
#   Test Accuracy: 82.70%
#
# --- Training Member 1 (Batch size: 256) ---
# built data in 1.5673620700836182 seconds
#  LR changed during epoch: 1.71e-04 -> 2.56e-04
# total runtime to train this model was 63.45462942123413 seconds
# evaluation in 13.11817193031311 seconds
#   Loss: 0.3583
#   Train Accuracy: 87.42%
#   Test Accuracy: 82.79%
#
# ============================================================
# Epoch 38 Summary:
# ============================================================
# Time: 156.51s (Avg member: 78.25s)
# Population Mean Accuracy: 82.75%
# Best Member Accuracy: 82.79%
# Mean Batch Size: 256
# Mean Learning Rate: 5.52e-04
# Mean Weight Decay: 0.278
#
# ============================================================
# Epoch 39/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.592886209487915 seconds
#  LR changed during epoch: 2.35e-04 -> 2.17e-04
# total runtime to train this model was 63.65371870994568 seconds
# evaluation in 13.099501132965088 seconds
#   Loss: 0.3299
#   Train Accuracy: 88.20%
#   Test Accuracy: 82.12%
#
# --- Training Member 1 (Batch size: 256) ---
# built data in 1.5765953063964844 seconds
#  LR changed during epoch: 2.56e-04 -> 3.41e-04
# total runtime to train this model was 63.13266396522522 seconds
# evaluation in 12.938637256622314 seconds
#   Loss: 0.3949
#   Train Accuracy: 85.96%
#   Test Accuracy: 82.01%
#
# ============================================================
# Epoch 39 Summary:
# ============================================================
# Time: 156.00s (Avg member: 78.00s)
# Population Mean Accuracy: 82.06%
# Best Member Accuracy: 82.12%
# Mean Batch Size: 256
# Mean Learning Rate: 5.52e-04
# Mean Weight Decay: 0.278
#
# ============================================================
# Epoch 40/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5783629417419434 seconds
#  LR changed during epoch: 2.17e-04 -> 1.99e-04
# total runtime to train this model was 63.372511863708496 seconds
# evaluation in 13.057408571243286 seconds
#   Loss: 0.3197
#   Train Accuracy: 88.57%
#   Test Accuracy: 82.48%
#
# --- Training Member 1 (Batch size: 256) ---
# built data in 1.569796085357666 seconds
#  LR changed during epoch: 3.41e-04 -> 4.26e-04
# total runtime to train this model was 63.554075956344604 seconds
# evaluation in 13.007835149765015 seconds
#   Loss: 0.4213
#   Train Accuracy: 85.07%
#   Test Accuracy: 80.99%
#
# --- Population Update (Epoch 40) ---
#
# === PBT Exploit & Explore ===
# Truncating 1 members
# Top performers: ['82.48%']
# Bottom performers: ['80.99%']
# Member 1: lr changed from 0.00042596476206306166 to 0.0002714986220279812
# Member 1: weight_decay changed from 0.25845150695245805 to 0.21930242719942816
# Member 1: drop_path changed from 0.1347297918264889 to 0.16656162594932722
# Member 1: batch_size changed from 256 to 128
# Member 1 copied from 0
#   LR=2.71e-04, WD=0.219, DropPath=0.167, Warmup=5 epochs, Batch=128
#
# ============================================================
# Epoch 40 Summary:
# ============================================================
# Time: 156.15s (Avg member: 78.07s)
# Population Mean Accuracy: 81.73%
# Best Member Accuracy: 82.48%
# Mean Batch Size: 192
# Mean Learning Rate: 4.75e-04
# Mean Weight Decay: 0.259
#
# ============================================================
# Epoch 41/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5833086967468262 seconds
#  LR changed during epoch: 1.99e-04 -> 1.82e-04
# total runtime to train this model was 63.47063183784485 seconds
# evaluation in 13.074619770050049 seconds
#   Loss: 0.3007
#   Train Accuracy: 89.48%
#   Test Accuracy: 83.34%
#
# --- Training Member 1 (Batch size: 128) ---
# built data in 1.569183588027954 seconds
#  LR changed during epoch: 1.39e-07 -> 5.44e-05
# total runtime to train this model was 65.30878043174744 seconds
# evaluation in 13.141928911209106 seconds
#   Loss: 0.2693
#   Train Accuracy: 90.54%
#   Test Accuracy: 84.21%
#
# ============================================================
# Epoch 41 Summary:
# ============================================================
# Time: 158.15s (Avg member: 79.08s)
# Population Mean Accuracy: 83.78%
# Best Member Accuracy: 84.21%
# Mean Batch Size: 192
# Mean Learning Rate: 4.75e-04
# Mean Weight Decay: 0.259
#
# ============================================================
# Epoch 42/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5860791206359863 seconds
#  LR changed during epoch: 1.82e-04 -> 1.65e-04
# total runtime to train this model was 63.43889045715332 seconds
# evaluation in 12.99658989906311 seconds
#   Loss: 0.2819
#   Train Accuracy: 90.03%
#   Test Accuracy: 82.78%
#
# --- Training Member 1 (Batch size: 128) ---
# built data in 1.5724966526031494 seconds
#  LR changed during epoch: 5.44e-05 -> 1.09e-04
# total runtime to train this model was 64.97930765151978 seconds
# evaluation in 13.110564708709717 seconds
#   Loss: 0.2770
#   Train Accuracy: 90.31%
#   Test Accuracy: 83.42%
#
# ...
#   Test Accuracy: 80.75%
#
# ============================================================
# Epoch 49 Summary:
# ============================================================
# Time: 157.40s (Avg member: 78.70s)
# Population Mean Accuracy: 82.31%
# Best Member Accuracy: 83.87%
# Mean Batch Size: 192
# Mean Learning Rate: 5.36e-04
# Mean Weight Decay: 0.271
#
# ============================================================
# Epoch 50/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5825204849243164 seconds
#  LR changed during epoch: 6.56e-05 -> 5.47e-05
# total runtime to train this model was 63.517815828323364 seconds
# evaluation in 13.12251353263855 seconds
#   Loss: 0.1632
#   Train Accuracy: 94.28%
#   Test Accuracy: 83.85%
#
# --- Training Member 1 (Batch size: 128) ---
# built data in 1.5666186809539795 seconds
#  LR changed during epoch: 3.15e-04 -> 3.93e-04
# total runtime to train this model was 64.88075137138367 seconds
# evaluation in 12.96946406364441 seconds
#   Loss: 0.4361
#   Train Accuracy: 84.52%
#   Test Accuracy: 79.98%
#
# --- Population Update (Epoch 50) ---
#
# === PBT Exploit & Explore ===
# Truncating 1 members
# Top performers: ['83.85%']
# Bottom performers: ['79.98%']
# Member 1: lr changed from 0.000392949070366709 to 0.00044986016063025666
# Member 1: weight_decay changed from 0.24474326343886477 to 0.2732166601130944
# Member 1: drop_path changed from 0.18491194553556622 to 0.15108121880876121
# Member 1 copied from 0
#   LR=4.50e-04, WD=0.273, DropPath=0.151, Warmup=5 epochs, Batch=128
#
# ============================================================
# Epoch 50 Summary:
# ============================================================
# Time: 157.65s (Avg member: 78.82s)
# Population Mean Accuracy: 81.91%
# Best Member Accuracy: 83.85%
# Mean Batch Size: 192
# Mean Learning Rate: 5.64e-04
# Mean Weight Decay: 0.286
#
# ============================================================
# Epoch 51/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.588655710220337 seconds
#  LR changed during epoch: 5.47e-05 -> 4.47e-05
# total runtime to train this model was 63.490368127822876 seconds
# evaluation in 13.139995336532593 seconds
#   Loss: 0.1522
#   Train Accuracy: 94.63%
#   Test Accuracy: 84.21%
#
# --- Training Member 1 (Batch size: 128) ---
# built data in 1.5773341655731201 seconds
#  LR changed during epoch: 2.30e-07 -> 9.02e-05
# total runtime to train this model was 64.49936103820801 seconds
# evaluation in 12.98530650138855 seconds
#   Loss: 0.1899
#   Train Accuracy: 93.37%
#   Test Accuracy: 83.71%
#
# ============================================================
# Epoch 51 Summary:
# ============================================================
# Time: 157.28s (Avg member: 78.64s)
# Population Mean Accuracy: 83.96%
# Best Member Accuracy: 84.21%
# Mean Batch Size: 192
# Mean Learning Rate: 5.64e-04
# Mean Weight Decay: 0.286
#
# ============================================================
# Epoch 52/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5894775390625 seconds
#  LR changed during epoch: 4.47e-05 -> 3.57e-05
# total runtime to train this model was 63.54713296890259 seconds
# evaluation in 13.127791404724121 seconds
#   Loss: 0.1437
#   Train Accuracy: 94.91%
#   Test Accuracy: 83.78%
#
# --- Training Member 1 (Batch size: 128) ---
# built data in 1.5676336288452148 seconds
#  LR changed during epoch: 9.02e-05 -> 1.80e-04
# total runtime to train this model was 64.86403489112854 seconds
# evaluation in 12.988012075424194 seconds
#   Loss: 0.2604
#   Train Accuracy: 90.69%
#   Test Accuracy: 81.97%
#
# ============================================================
# Epoch 52 Summary:
# ============================================================
# Time: 157.69s (Avg member: 78.84s)
# Population Mean Accuracy: 82.88%
# Best Member Accuracy: 83.78%
# Mean Batch Size: 192
# Mean Learning Rate: 5.64e-04
# Mean Weight Decay: 0.286
#
# ============================================================
# Epoch 53/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.6083145141601562 seconds
#  LR changed during epoch: 3.57e-05 -> 2.77e-05
# total runtime to train this model was 63.39569449424744 seconds
# evaluation in 13.016203165054321 seconds
#   Loss: 0.1317
#   Train Accuracy: 95.33%
#   Test Accuracy: 84.26%
#
# --- Training Member 1 (Batch size: 128) ---
# built data in 1.5688323974609375 seconds
#  LR changed during epoch: 1.80e-04 -> 2.70e-04
# total runtime to train this model was 65.30890202522278 seconds
# evaluation in 13.1047043800354 seconds
#   Loss: 0.3444
#   Train Accuracy: 87.76%
#   Test Accuracy: 81.66%
#
# ============================================================
# Epoch 53 Summary:
# ============================================================
# Time: 158.01s (Avg member: 79.00s)
# Population Mean Accuracy: 82.96%
# Best Member Accuracy: 84.26%
# Mean Batch Size: 192
# Mean Learning Rate: 5.64e-04
# Mean Weight Decay: 0.286
#
# ============================================================
# Epoch 54/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5856592655181885 seconds
#  LR changed during epoch: 2.77e-05 -> 2.07e-05
# total runtime to train this model was 63.73093247413635 seconds
# evaluation in 13.134629964828491 seconds
#   Loss: 0.1264
#   Train Accuracy: 95.66%
#   Test Accuracy: 84.07%
#
# --- Training Member 1 (Batch size: 128) ---
# built data in 1.5651450157165527 seconds
#  LR changed during epoch: 2.70e-04 -> 3.60e-04
# total runtime to train this model was 64.92805552482605 seconds
# evaluation in 13.013049125671387 seconds
#   Loss: 0.4036
#   Train Accuracy: 85.51%
#   Test Accuracy: 80.01%
#
# ============================================================
# Epoch 54 Summary:
# ============================================================
# Time: 157.96s (Avg member: 78.98s)
# Population Mean Accuracy: 82.04%
# Best Member Accuracy: 84.07%
# Mean Batch Size: 192
# Mean Learning Rate: 5.64e-04
# Mean Weight Decay: 0.286
#
# ============================================================
# Epoch 55/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5840222835540771 seconds
#  LR changed during epoch: 2.07e-05 -> 1.47e-05
# total runtime to train this model was 63.571282148361206 seconds
# evaluation in 13.11722469329834 seconds
#   Loss: 0.1186
#   Train Accuracy: 95.84%
#   Test Accuracy: 84.19%
#
# --- Training Member 1 (Batch size: 128) ---
# built data in 1.5736722946166992 seconds
#  LR changed during epoch: 3.60e-04 -> 4.50e-04
# total runtime to train this model was 65.09217953681946 seconds
# evaluation in 13.060533046722412 seconds
#   Loss: 0.4692
#   Train Accuracy: 83.38%
#   Test Accuracy: 78.25%
#
# --- Population Update (Epoch 55) ---
#
# === PBT Exploit & Explore ===
# Truncating 1 members
# Top performers: ['84.19%']
# Bottom performers: ['78.25%']
# Member 1: lr changed from 0.00044986016063025666 to 0.0005499239718497498
# Member 1: weight_decay changed from 0.2732166601130944 to 0.22538269464371274
# Member 1: drop_path changed from 0.15108121880876121 to 0.12843062595487706
# Member 1 copied from 0
#   LR=5.50e-04, WD=0.225, DropPath=0.128, Warmup=5 epochs, Batch=128
#
# ============================================================
# Epoch 55 Summary:
# ============================================================
# Time: 158.01s (Avg member: 79.00s)
# Population Mean Accuracy: 81.22%
# Best Member Accuracy: 84.19%
# Mean Batch Size: 192
# Mean Learning Rate: 6.14e-04
# Mean Weight Decay: 0.262
#
# ============================================================
# Epoch 56/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5806210041046143 seconds
#  LR changed during epoch: 1.47e-05 -> 9.78e-06
# total runtime to train this model was 63.508270025253296 seconds
# evaluation in 13.056899785995483 seconds
#   Loss: 0.1167
#   Train Accuracy: 96.00%
#   Test Accuracy: 84.09%
#
# --- Training Member 1 (Batch size: 128) ---
# built data in 1.5726308822631836 seconds
#  LR changed during epoch: 2.81e-07 -> 1.10e-04
# total runtime to train this model was 64.99724078178406 seconds
# evaluation in 13.126080513000488 seconds
#   Loss: 0.1747
#   Train Accuracy: 93.91%
#   Test Accuracy: 83.53%
#
# ============================================================
# Epoch 56 Summary:
# ============================================================
# Time: 157.84s (Avg member: 78.92s)
# Population Mean Accuracy: 83.81%
# Best Member Accuracy: 84.09%
# Mean Batch Size: 192
# Mean Learning Rate: 6.14e-04
# Mean Weight Decay: 0.262
#
# ============================================================
# Epoch 57/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5896413326263428 seconds
#  LR changed during epoch: 9.78e-06 -> 5.94e-06
# total runtime to train this model was 63.48483395576477 seconds
# evaluation in 13.104881525039673 seconds
#   Loss: 0.1151
#   Train Accuracy: 96.06%
#   Test Accuracy: 84.54%
#
# --- Training Member 1 (Batch size: 128) ---
# built data in 1.572195053100586 seconds
#  LR changed during epoch: 1.10e-04 -> 2.20e-04
# total runtime to train this model was 65.35209083557129 seconds
# evaluation in 13.116908073425293 seconds
#   Loss: 0.2779
#   Train Accuracy: 90.07%
#   Test Accuracy: 81.94%
#
# ============================================================
# Epoch 57 Summary:
# ============================================================
# Time: 158.22s (Avg member: 79.11s)
# Population Mean Accuracy: 83.24%
# Best Member Accuracy: 84.54%
# Mean Batch Size: 192
# Mean Learning Rate: 6.14e-04
# Mean Weight Decay: 0.262
#
# ============================================================
# Epoch 58/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5831260681152344 seconds
#  LR changed during epoch: 5.94e-06 -> 3.20e-06
# total runtime to train this model was 63.42137169837952 seconds
# evaluation in 12.962185382843018 seconds
#   Loss: 0.1104
#   Train Accuracy: 96.20%
#   Test Accuracy: 84.50%
#
# --- Training Member 1 (Batch size: 128) ---
# built data in 1.569631814956665 seconds
#  LR changed during epoch: 2.20e-04 -> 3.30e-04
# total runtime to train this model was 65.1271903514862 seconds
# evaluation in 13.073570251464844 seconds
#   Loss: 0.3703
#   Train Accuracy: 86.85%
#   Test Accuracy: 81.10%
#
# ============================================================
# Epoch 58 Summary:
# ============================================================
# Time: 157.74s (Avg member: 78.87s)
# Population Mean Accuracy: 82.80%
# Best Member Accuracy: 84.50%
# Mean Batch Size: 192
# Mean Learning Rate: 6.14e-04
# Mean Weight Decay: 0.262
#
# ============================================================
# Epoch 59/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5927159786224365 seconds
#  LR changed during epoch: 3.20e-06 -> 1.55e-06
# total runtime to train this model was 63.498008251190186 seconds
# evaluation in 13.144768953323364 seconds
#   Loss: 0.1086
#   Train Accuracy: 96.24%
#   Test Accuracy: 84.55%
#
# --- Training Member 1 (Batch size: 128) ---
# built data in 1.564852237701416 seconds
#  LR changed during epoch: 3.30e-04 -> 4.40e-04
# total runtime to train this model was 64.71612501144409 seconds
# evaluation in 12.952695608139038 seconds
#   Loss: 0.4472
#   Train Accuracy: 83.99%
#   Test Accuracy: 79.38%
#
# ============================================================
# Epoch 59 Summary:
# ============================================================
# Time: 157.47s (Avg member: 78.74s)
# Population Mean Accuracy: 81.97%
# Best Member Accuracy: 84.55%
# Mean Batch Size: 192
# Mean Learning Rate: 6.14e-04
# Mean Weight Decay: 0.262
#
# ============================================================
# Epoch 60/60
# ============================================================
#
# --- Training Member 0 (Batch size: 256) ---
# built data in 1.5814762115478516 seconds
#  LR changed during epoch: 1.55e-06 -> 1.00e-06
# total runtime to train this model was 63.549094676971436 seconds
# evaluation in 13.060111045837402 seconds
#   Loss: 0.1082
#   Train Accuracy: 96.31%
#   Test Accuracy: 84.51%
#
# --- Training Member 1 (Batch size: 128) ---
# built data in 1.575800895690918 seconds
#  LR changed during epoch: 4.40e-04 -> 5.50e-04
# total runtime to train this model was 65.37323570251465 seconds
# evaluation in 13.068952083587646 seconds
#   Loss: 0.5077
#   Train Accuracy: 81.91%
#   Test Accuracy: 78.46%
#
# --- Population Update (Epoch 60) ---
#
# === PBT Exploit & Explore ===
# Truncating 1 members
# Top performers: ['84.51%']
# Bottom performers: ['78.46%']
# Member 1: lr changed from 0.0005499239718497498 to 0.0004771772851697156
# Member 1: weight_decay changed from 0.22538269464371274 to 0.26122287262756855
# Member 1: drop_path changed from 0.12843062595487706 to 0.11734818901908842
# Member 1: batch_size changed from 128 to 64
# Member 1 copied from 0
#   LR=4.77e-04, WD=0.261, DropPath=0.117, Warmup=5 epochs, Batch=64
#
# ============================================================
# Epoch 60 Summary:
# ============================================================
# Time: 158.22s (Avg member: 79.11s)
# Population Mean Accuracy: 81.48%
# Best Member Accuracy: 84.51%
# Mean Batch Size: 160
# Mean Learning Rate: 5.78e-04
# Mean Weight Decay: 0.280
#
# ======================================================================
#                         PBT TRAINING COMPLETE
# ======================================================================
# Best member: 0
# Best accuracy: 84.51%
#
# Best hyperparameters:
#   Learning Rate: 6.78e-04
#   Weight Decay: 0.298
#   Drop Path Rate: 0.103
#   Warmup Epochs: 5
#   Batch Size: 256
#
# ======================================================================
#                           PBT TIMING REPORT
# ======================================================================
#
# Overall Statistics                       Value
# ----------------------------------------------------------------------
# Total runtime                            9528.79s (158.81 min)
# Number of epochs                         60
# Number of population updates             12
#
# Epoch Timing                             Value
# ----------------------------------------------------------------------
# Average epoch time                       158.80s
# Std epoch time                           1.83s
# Min epoch time                           155.74s (epoch 31)
# Max epoch time                           161.30s (epoch 14)
#
# Member Training Timing                   Value
# ----------------------------------------------------------------------
# Average member time per epoch            79.40s
# Total training time                      9528.04s
# Training efficiency                      100.0%
#
# Population Update Timing                 Value
# ----------------------------------------------------------------------
# Average update time                      0.01s
# Total update time                        0.11s
# Update efficiency                        0.0%
#
# Batch Size Analysis                      Avg Time        Samples
# ----------------------------------------------------------------------
# Batch size 64                            82.81s      25
# Batch size 128                           79.67s      25
# Batch size 256                           78.08s      70
#
# Per-Member Statistics                    Avg Time        Total Time
# ----------------------------------------------------------------------
# Member 0                                 78.10s      4685.92s
# Member 1                                 80.70s      4842.11s
#
# ======================================================================
# Experiment completed successfully!
# Results saved to: pbt_vit_timing_results.png
# Detailed timing saved to: pbt_detailed_timing.png
